# %%
import numpy as np
from som import SOM

# %%
# generate some random data with 36 features
data1 = np.random.normal(loc=-.25, scale=0.5, size=(500, 36))
data2 = np.random.normal(loc=.25, scale=0.5, size=(500, 36))
data = np.vstack((data1, data2))

# %%
data.dtype
# Out:
# dtype('float64')

# %%
data.shape
# Out:
# (1000, 36)

# %%
som = SOM(10, 10)  # initialize a 10 by 10 SOM
som.fit(data, 1000, save_e=True, interval=100)  # fit the SOM for 10000 epochs, save the error every 100 steps
som.plot_error_history(filename='images/som_error.png')  # plot the training error history
# Out:
# Epoch 0;    Neuron [4, 5];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 1;    Neuron [6, 9];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 2;    Neuron [6, 0];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 3;    Neuron [3, 6];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 4;    Neuron [3, 2];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 5;    Neuron [8, 1];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 6;    Neuron [6, 9];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 7;    Neuron [2, 6];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 8;    Neuron [8, 3];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 9;    Neuron [0, 0];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 10;    Neuron [8, 1];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 11;    Neuron [4, 7];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 12;    Neuron [0, 3];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 13;    Neuron [3, 6];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 14;    Neuron [5, 1];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 15;    Neuron [1, 8];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 16;    Neuron [4, 8];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 17;    Neuron [3, 3];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 18;    Neuron [1, 6];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 19;    Neuron [2, 1];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 20;    Neuron [8, 2];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 21;    Neuron [5, 6];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 22;    Neuron [7, 3];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 23;    Neuron [9, 0];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 24;    Neuron [0, 4];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 25;    Neuron [4, 8];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 26;    Neuron [8, 1];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 27;    Neuron [6, 3];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 28;    Neuron [9, 5];    	Sigma: 5.0000;    alpha: 0.6000
# Epoch 29;    Neuron [2, 7];    	Sigma: 4.9999;    alpha: 0.6000
# Epoch 30;    Neuron [8, 0];    	Sigma: 4.9999;    alpha: 0.6000
# Epoch 31;    Neuron [7, 4];    	Sigma: 4.9999;    alpha: 0.6000
# Epoch 32;    Neuron [3, 5];    	Sigma: 4.9999;    alpha: 0.6000
# Epoch 33;    Neuron [0, 1];    	Sigma: 4.9999;    alpha: 0.6000
# Epoch 34;    Neuron [4, 0];    	Sigma: 4.9999;    alpha: 0.6000
# Epoch 35;    Neuron [2, 7];    	Sigma: 4.9999;    alpha: 0.6000
# Epoch 36;    Neuron [7, 7];    	Sigma: 4.9999;    alpha: 0.6000
# Epoch 37;    Neuron [5, 2];    	Sigma: 4.9998;    alpha: 0.6000
# Epoch 38;    Neuron [1, 6];    	Sigma: 4.9998;    alpha: 0.6000
# Epoch 39;    Neuron [0, 1];    	Sigma: 4.9998;    alpha: 0.6000
# Epoch 40;    Neuron [4, 6];    	Sigma: 4.9998;    alpha: 0.6000
# Epoch 41;    Neuron [2, 8];    	Sigma: 4.9998;    alpha: 0.6000
# Epoch 42;    Neuron [8, 6];    	Sigma: 4.9998;    alpha: 0.6000
# Epoch 43;    Neuron [6, 0];    	Sigma: 4.9997;    alpha: 0.6000
# Epoch 44;    Neuron [7, 3];    	Sigma: 4.9997;    alpha: 0.6000
# Epoch 45;    Neuron [4, 2];    	Sigma: 4.9997;    alpha: 0.6000
# Epoch 46;    Neuron [9, 2];    	Sigma: 4.9996;    alpha: 0.6000
# Epoch 47;    Neuron [4, 4];    	Sigma: 4.9996;    alpha: 0.6000
# Epoch 48;    Neuron [6, 5];    	Sigma: 4.9996;    alpha: 0.5999
# Epoch 49;    Neuron [8, 9];    	Sigma: 4.9995;    alpha: 0.5999
# Epoch 50;    Neuron [9, 2];    	Sigma: 4.9995;    alpha: 0.5999
# Epoch 51;    Neuron [0, 2];    	Sigma: 4.9995;    alpha: 0.5999
# Epoch 52;    Neuron [2, 7];    	Sigma: 4.9994;    alpha: 0.5999
# Epoch 53;    Neuron [5, 6];    	Sigma: 4.9994;    alpha: 0.5999
# Epoch 54;    Neuron [7, 2];    	Sigma: 4.9993;    alpha: 0.5999
# Epoch 55;    Neuron [3, 9];    	Sigma: 4.9993;    alpha: 0.5999
# Epoch 56;    Neuron [0, 6];    	Sigma: 4.9992;    alpha: 0.5999
# Epoch 57;    Neuron [9, 3];    	Sigma: 4.9992;    alpha: 0.5999
# Epoch 58;    Neuron [5, 8];    	Sigma: 4.9991;    alpha: 0.5999
# Epoch 59;    Neuron [2, 9];    	Sigma: 4.9990;    alpha: 0.5999
# Epoch 60;    Neuron [7, 2];    	Sigma: 4.9990;    alpha: 0.5999
# Epoch 61;    Neuron [4, 5];    	Sigma: 4.9989;    alpha: 0.5999
# Epoch 62;    Neuron [9, 8];    	Sigma: 4.9988;    alpha: 0.5999
# Epoch 63;    Neuron [6, 5];    	Sigma: 4.9987;    alpha: 0.5998
# Epoch 64;    Neuron [0, 3];    	Sigma: 4.9987;    alpha: 0.5998
# Epoch 65;    Neuron [5, 8];    	Sigma: 4.9986;    alpha: 0.5998
# Epoch 66;    Neuron [8, 2];    	Sigma: 4.9985;    alpha: 0.5998
# Epoch 67;    Neuron [4, 3];    	Sigma: 4.9984;    alpha: 0.5998
# Epoch 68;    Neuron [2, 8];    	Sigma: 4.9983;    alpha: 0.5998
# Epoch 69;    Neuron [6, 9];    	Sigma: 4.9982;    alpha: 0.5998
# Epoch 70;    Neuron [9, 3];    	Sigma: 4.9981;    alpha: 0.5998
# Epoch 71;    Neuron [7, 8];    	Sigma: 4.9980;    alpha: 0.5998
# Epoch 72;    Neuron [6, 2];    	Sigma: 4.9978;    alpha: 0.5997
# Epoch 73;    Neuron [1, 3];    	Sigma: 4.9977;    alpha: 0.5997
# Epoch 74;    Neuron [9, 4];    	Sigma: 4.9976;    alpha: 0.5997
# Epoch 75;    Neuron [3, 5];    	Sigma: 4.9975;    alpha: 0.5997
# Epoch 76;    Neuron [2, 0];    	Sigma: 4.9973;    alpha: 0.5997
# Epoch 77;    Neuron [5, 8];    	Sigma: 4.9972;    alpha: 0.5997
# Epoch 78;    Neuron [4, 7];    	Sigma: 4.9970;    alpha: 0.5996
# Epoch 79;    Neuron [9, 4];    	Sigma: 4.9969;    alpha: 0.5996
# Epoch 80;    Neuron [7, 8];    	Sigma: 4.9967;    alpha: 0.5996
# Epoch 81;    Neuron [1, 2];    	Sigma: 4.9965;    alpha: 0.5996
# Epoch 82;    Neuron [6, 3];    	Sigma: 4.9964;    alpha: 0.5996
# Epoch 83;    Neuron [3, 8];    	Sigma: 4.9962;    alpha: 0.5995
# Epoch 84;    Neuron [9, 0];    	Sigma: 4.9960;    alpha: 0.5995
# Epoch 85;    Neuron [5, 7];    	Sigma: 4.9958;    alpha: 0.5995
# Epoch 86;    Neuron [0, 4];    	Sigma: 4.9956;    alpha: 0.5995
# Epoch 87;    Neuron [4, 9];    	Sigma: 4.9954;    alpha: 0.5994
# Epoch 88;    Neuron [9, 1];    	Sigma: 4.9952;    alpha: 0.5994
# Epoch 89;    Neuron [6, 2];    	Sigma: 4.9950;    alpha: 0.5994
# Epoch 90;    Neuron [5, 6];    	Sigma: 4.9947;    alpha: 0.5994
# Epoch 91;    Neuron [9, 3];    	Sigma: 4.9945;    alpha: 0.5993
# Epoch 92;    Neuron [3, 6];    	Sigma: 4.9943;    alpha: 0.5993
# Epoch 93;    Neuron [1, 2];    	Sigma: 4.9940;    alpha: 0.5993
# Epoch 94;    Neuron [9, 9];    	Sigma: 4.9937;    alpha: 0.5992
# Epoch 95;    Neuron [4, 8];    	Sigma: 4.9935;    alpha: 0.5992
# Epoch 96;    Neuron [2, 3];    	Sigma: 4.9932;    alpha: 0.5992
# Epoch 97;    Neuron [0, 7];    	Sigma: 4.9929;    alpha: 0.5991
# Epoch 98;    Neuron [5, 0];    	Sigma: 4.9926;    alpha: 0.5991
# Epoch 99;    Neuron [7, 2];    	Sigma: 4.9923;    alpha: 0.5991
# Epoch 100;    Neuron [9, 5];    	Sigma: 4.9920;    alpha: 0.5990
# Epoch 101;    Neuron [2, 3];    	Sigma: 4.9917;    alpha: 0.5990
# Epoch 102;    Neuron [6, 2];    	Sigma: 4.9913;    alpha: 0.5990
# Epoch 103;    Neuron [7, 1];    	Sigma: 4.9910;    alpha: 0.5989
# Epoch 104;    Neuron [4, 7];    	Sigma: 4.9906;    alpha: 0.5989
# Epoch 105;    Neuron [0, 4];    	Sigma: 4.9903;    alpha: 0.5988
# Epoch 106;    Neuron [8, 2];    	Sigma: 4.9899;    alpha: 0.5988
# Epoch 107;    Neuron [2, 8];    	Sigma: 4.9895;    alpha: 0.5987
# Epoch 108;    Neuron [9, 5];    	Sigma: 4.9891;    alpha: 0.5987
# Epoch 109;    Neuron [5, 3];    	Sigma: 4.9887;    alpha: 0.5986
# Epoch 110;    Neuron [3, 9];    	Sigma: 4.9883;    alpha: 0.5986
# Epoch 111;    Neuron [8, 0];    	Sigma: 4.9878;    alpha: 0.5985
# Epoch 112;    Neuron [5, 4];    	Sigma: 4.9874;    alpha: 0.5985
# Epoch 113;    Neuron [3, 8];    	Sigma: 4.9869;    alpha: 0.5984
# Epoch 114;    Neuron [4, 9];    	Sigma: 4.9865;    alpha: 0.5984
# Epoch 115;    Neuron [9, 3];    	Sigma: 4.9860;    alpha: 0.5983
# Epoch 116;    Neuron [2, 7];    	Sigma: 4.9855;    alpha: 0.5983
# Epoch 117;    Neuron [6, 4];    	Sigma: 4.9850;    alpha: 0.5982
# Epoch 118;    Neuron [8, 3];    	Sigma: 4.9845;    alpha: 0.5981
# Epoch 119;    Neuron [1, 5];    	Sigma: 4.9839;    alpha: 0.5981
# Epoch 120;    Neuron [5, 9];    	Sigma: 4.9834;    alpha: 0.5980
# Epoch 121;    Neuron [3, 9];    	Sigma: 4.9828;    alpha: 0.5979
# Epoch 122;    Neuron [0, 2];    	Sigma: 4.9823;    alpha: 0.5979
# Epoch 123;    Neuron [5, 4];    	Sigma: 4.9817;    alpha: 0.5978
# Epoch 124;    Neuron [8, 6];    	Sigma: 4.9811;    alpha: 0.5977
# Epoch 125;    Neuron [2, 1];    	Sigma: 4.9805;    alpha: 0.5977
# Epoch 126;    Neuron [9, 2];    	Sigma: 4.9798;    alpha: 0.5976
# Epoch 127;    Neuron [6, 9];    	Sigma: 4.9792;    alpha: 0.5975
# Epoch 128;    Neuron [3, 8];    	Sigma: 4.9785;    alpha: 0.5974
# Epoch 129;    Neuron [0, 5];    	Sigma: 4.9779;    alpha: 0.5973
# Epoch 130;    Neuron [5, 4];    	Sigma: 4.9772;    alpha: 0.5973
# Epoch 131;    Neuron [8, 6];    	Sigma: 4.9765;    alpha: 0.5972
# Epoch 132;    Neuron [1, 3];    	Sigma: 4.9757;    alpha: 0.5971
# Epoch 133;    Neuron [3, 9];    	Sigma: 4.9750;    alpha: 0.5970
# Epoch 134;    Neuron [6, 9];    	Sigma: 4.9742;    alpha: 0.5969
# Epoch 135;    Neuron [2, 8];    	Sigma: 4.9735;    alpha: 0.5968
# Epoch 136;    Neuron [8, 4];    	Sigma: 4.9727;    alpha: 0.5967
# Epoch 137;    Neuron [6, 9];    	Sigma: 4.9719;    alpha: 0.5966
# Epoch 138;    Neuron [3, 4];    	Sigma: 4.9710;    alpha: 0.5965
# Epoch 139;    Neuron [0, 8];    	Sigma: 4.9702;    alpha: 0.5964
# Epoch 140;    Neuron [4, 0];    	Sigma: 4.9693;    alpha: 0.5963
# Epoch 141;    Neuron [9, 3];    	Sigma: 4.9685;    alpha: 0.5962
# Epoch 142;    Neuron [7, 8];    	Sigma: 4.9676;    alpha: 0.5961
# Epoch 143;    Neuron [4, 7];    	Sigma: 4.9666;    alpha: 0.5960
# Epoch 144;    Neuron [9, 6];    	Sigma: 4.9657;    alpha: 0.5959
# Epoch 145;    Neuron [5, 1];    	Sigma: 4.9647;    alpha: 0.5958
# Epoch 146;    Neuron [1, 2];    	Sigma: 4.9638;    alpha: 0.5957
# Epoch 147;    Neuron [8, 3];    	Sigma: 4.9628;    alpha: 0.5955
# Epoch 148;    Neuron [0, 0];    	Sigma: 4.9618;    alpha: 0.5954
# Epoch 149;    Neuron [5, 9];    	Sigma: 4.9607;    alpha: 0.5953
# Epoch 150;    Neuron [5, 5];    	Sigma: 4.9597;    alpha: 0.5952
# Epoch 151;    Neuron [2, 7];    	Sigma: 4.9586;    alpha: 0.5950
# Epoch 152;    Neuron [3, 2];    	Sigma: 4.9575;    alpha: 0.5949
# Epoch 153;    Neuron [2, 9];    	Sigma: 4.9564;    alpha: 0.5948
# Epoch 154;    Neuron [9, 1];    	Sigma: 4.9552;    alpha: 0.5946
# Epoch 155;    Neuron [7, 2];    	Sigma: 4.9541;    alpha: 0.5945
# Epoch 156;    Neuron [9, 6];    	Sigma: 4.9529;    alpha: 0.5943
# Epoch 157;    Neuron [7, 3];    	Sigma: 4.9517;    alpha: 0.5942
# Epoch 158;    Neuron [6, 0];    	Sigma: 4.9504;    alpha: 0.5941
# Epoch 159;    Neuron [3, 7];    	Sigma: 4.9492;    alpha: 0.5939
# Epoch 160;    Neuron [8, 0];    	Sigma: 4.9479;    alpha: 0.5937
# Epoch 161;    Neuron [2, 8];    	Sigma: 4.9466;    alpha: 0.5936
# Epoch 162;    Neuron [5, 3];    	Sigma: 4.9453;    alpha: 0.5934
# Epoch 163;    Neuron [0, 2];    	Sigma: 4.9439;    alpha: 0.5933
# Epoch 164;    Neuron [9, 7];    	Sigma: 4.9426;    alpha: 0.5931
# Epoch 165;    Neuron [2, 7];    	Sigma: 4.9412;    alpha: 0.5929
# Epoch 166;    Neuron [7, 1];    	Sigma: 4.9397;    alpha: 0.5928
# Epoch 167;    Neuron [4, 6];    	Sigma: 4.9383;    alpha: 0.5926
# Epoch 168;    Neuron [3, 4];    	Sigma: 4.9368;    alpha: 0.5924
# Epoch 169;    Neuron [8, 3];    	Sigma: 4.9353;    alpha: 0.5922
# Epoch 170;    Neuron [4, 8];    	Sigma: 4.9338;    alpha: 0.5921
# Epoch 171;    Neuron [0, 0];    	Sigma: 4.9323;    alpha: 0.5919
# Epoch 172;    Neuron [9, 7];    	Sigma: 4.9307;    alpha: 0.5917
# Epoch 173;    Neuron [7, 2];    	Sigma: 4.9291;    alpha: 0.5915
# Epoch 174;    Neuron [1, 3];    	Sigma: 4.9274;    alpha: 0.5913
# Epoch 175;    Neuron [5, 6];    	Sigma: 4.9258;    alpha: 0.5911
# Epoch 176;    Neuron [7, 3];    	Sigma: 4.9241;    alpha: 0.5909
# Epoch 177;    Neuron [9, 1];    	Sigma: 4.9224;    alpha: 0.5907
# Epoch 178;    Neuron [3, 8];    	Sigma: 4.9206;    alpha: 0.5905
# Epoch 179;    Neuron [5, 1];    	Sigma: 4.9189;    alpha: 0.5903
# Epoch 180;    Neuron [1, 9];    	Sigma: 4.9171;    alpha: 0.5900
# Epoch 181;    Neuron [3, 6];    	Sigma: 4.9153;    alpha: 0.5898
# Epoch 182;    Neuron [1, 7];    	Sigma: 4.9134;    alpha: 0.5896
# Epoch 183;    Neuron [6, 6];    	Sigma: 4.9115;    alpha: 0.5894
# Epoch 184;    Neuron [8, 2];    	Sigma: 4.9096;    alpha: 0.5892
# Epoch 185;    Neuron [3, 9];    	Sigma: 4.9077;    alpha: 0.5889
# Epoch 186;    Neuron [4, 5];    	Sigma: 4.9057;    alpha: 0.5887
# Epoch 187;    Neuron [3, 0];    	Sigma: 4.9037;    alpha: 0.5884
# Epoch 188;    Neuron [8, 2];    	Sigma: 4.9016;    alpha: 0.5882
# Epoch 189;    Neuron [1, 2];    	Sigma: 4.8996;    alpha: 0.5879
# Epoch 190;    Neuron [3, 8];    	Sigma: 4.8975;    alpha: 0.5877
# Epoch 191;    Neuron [8, 4];    	Sigma: 4.8953;    alpha: 0.5874
# Epoch 192;    Neuron [6, 7];    	Sigma: 4.8932;    alpha: 0.5872
# Epoch 193;    Neuron [9, 3];    	Sigma: 4.8910;    alpha: 0.5869
# Epoch 194;    Neuron [4, 3];    	Sigma: 4.8888;    alpha: 0.5867
# Epoch 195;    Neuron [4, 8];    	Sigma: 4.8865;    alpha: 0.5864
# Epoch 196;    Neuron [6, 8];    	Sigma: 4.8842;    alpha: 0.5861
# Epoch 197;    Neuron [1, 3];    	Sigma: 4.8819;    alpha: 0.5858
# Epoch 198;    Neuron [2, 8];    	Sigma: 4.8795;    alpha: 0.5855
# Epoch 199;    Neuron [8, 8];    	Sigma: 4.8771;    alpha: 0.5853
# Epoch 200;    Neuron [1, 6];    	Sigma: 4.8747;    alpha: 0.5850
# Epoch 201;    Neuron [7, 2];    	Sigma: 4.8722;    alpha: 0.5847
# Epoch 202;    Neuron [5, 7];    	Sigma: 4.8698;    alpha: 0.5844
# Epoch 203;    Neuron [3, 0];    	Sigma: 4.8672;    alpha: 0.5841
# Epoch 204;    Neuron [0, 3];    	Sigma: 4.8647;    alpha: 0.5838
# Epoch 205;    Neuron [1, 8];    	Sigma: 4.8621;    alpha: 0.5834
# Epoch 206;    Neuron [8, 3];    	Sigma: 4.8594;    alpha: 0.5831
# Epoch 207;    Neuron [9, 6];    	Sigma: 4.8568;    alpha: 0.5828
# Epoch 208;    Neuron [6, 8];    	Sigma: 4.8540;    alpha: 0.5825
# Epoch 209;    Neuron [4, 7];    	Sigma: 4.8513;    alpha: 0.5822
# Epoch 210;    Neuron [9, 1];    	Sigma: 4.8485;    alpha: 0.5818
# Epoch 211;    Neuron [2, 3];    	Sigma: 4.8457;    alpha: 0.5815
# Epoch 212;    Neuron [7, 4];    	Sigma: 4.8429;    alpha: 0.5811
# Epoch 213;    Neuron [3, 1];    	Sigma: 4.8400;    alpha: 0.5808
# Epoch 214;    Neuron [4, 8];    	Sigma: 4.8370;    alpha: 0.5804
# Epoch 215;    Neuron [8, 2];    	Sigma: 4.8341;    alpha: 0.5801
# Epoch 216;    Neuron [1, 8];    	Sigma: 4.8311;    alpha: 0.5797
# Epoch 217;    Neuron [7, 5];    	Sigma: 4.8280;    alpha: 0.5794
# Epoch 218;    Neuron [5, 4];    	Sigma: 4.8249;    alpha: 0.5790
# Epoch 219;    Neuron [6, 2];    	Sigma: 4.8218;    alpha: 0.5786
# Epoch 220;    Neuron [7, 7];    	Sigma: 4.8187;    alpha: 0.5782
# Epoch 221;    Neuron [2, 4];    	Sigma: 4.8155;    alpha: 0.5779
# Epoch 222;    Neuron [2, 9];    	Sigma: 4.8122;    alpha: 0.5775
# Epoch 223;    Neuron [7, 0];    	Sigma: 4.8090;    alpha: 0.5771
# Epoch 224;    Neuron [0, 8];    	Sigma: 4.8056;    alpha: 0.5767
# Epoch 225;    Neuron [2, 7];    	Sigma: 4.8023;    alpha: 0.5763
# Epoch 226;    Neuron [4, 9];    	Sigma: 4.7989;    alpha: 0.5759
# Epoch 227;    Neuron [8, 4];    	Sigma: 4.7955;    alpha: 0.5755
# Epoch 228;    Neuron [9, 9];    	Sigma: 4.7920;    alpha: 0.5750
# Epoch 229;    Neuron [3, 2];    	Sigma: 4.7885;    alpha: 0.5746
# Epoch 230;    Neuron [5, 9];    	Sigma: 4.7849;    alpha: 0.5742
# Epoch 231;    Neuron [8, 3];    	Sigma: 4.7813;    alpha: 0.5738
# Epoch 232;    Neuron [2, 6];    	Sigma: 4.7777;    alpha: 0.5733
# Epoch 233;    Neuron [6, 5];    	Sigma: 4.7740;    alpha: 0.5729
# Epoch 234;    Neuron [3, 9];    	Sigma: 4.7702;    alpha: 0.5724
# Epoch 235;    Neuron [2, 1];    	Sigma: 4.7665;    alpha: 0.5720
# Epoch 236;    Neuron [7, 7];    	Sigma: 4.7627;    alpha: 0.5715
# Epoch 237;    Neuron [7, 4];    	Sigma: 4.7588;    alpha: 0.5711
# Epoch 238;    Neuron [9, 0];    	Sigma: 4.7549;    alpha: 0.5706
# Epoch 239;    Neuron [9, 3];    	Sigma: 4.7510;    alpha: 0.5701
# Epoch 240;    Neuron [3, 0];    	Sigma: 4.7470;    alpha: 0.5696
# Epoch 241;    Neuron [0, 5];    	Sigma: 4.7430;    alpha: 0.5692
# Epoch 242;    Neuron [4, 8];    	Sigma: 4.7389;    alpha: 0.5687
# Epoch 243;    Neuron [8, 2];    	Sigma: 4.7348;    alpha: 0.5682
# Epoch 244;    Neuron [2, 9];    	Sigma: 4.7306;    alpha: 0.5677
# Epoch 245;    Neuron [7, 3];    	Sigma: 4.7264;    alpha: 0.5672
# Epoch 246;    Neuron [5, 8];    	Sigma: 4.7222;    alpha: 0.5667
# Epoch 247;    Neuron [3, 7];    	Sigma: 4.7179;    alpha: 0.5661
# Epoch 248;    Neuron [0, 4];    	Sigma: 4.7136;    alpha: 0.5656
# Epoch 249;    Neuron [3, 1];    	Sigma: 4.7092;    alpha: 0.5651
# Epoch 250;    Neuron [5, 0];    	Sigma: 4.7048;    alpha: 0.5646
# Epoch 251;    Neuron [4, 6];    	Sigma: 4.7003;    alpha: 0.5640
# Epoch 252;    Neuron [8, 5];    	Sigma: 4.6958;    alpha: 0.5635
# Epoch 253;    Neuron [5, 9];    	Sigma: 4.6912;    alpha: 0.5629
# Epoch 254;    Neuron [9, 0];    	Sigma: 4.6866;    alpha: 0.5624
# Epoch 255;    Neuron [7, 8];    	Sigma: 4.6820;    alpha: 0.5618
# Epoch 256;    Neuron [2, 7];    	Sigma: 4.6773;    alpha: 0.5613
# Epoch 257;    Neuron [0, 3];    	Sigma: 4.6726;    alpha: 0.5607
# Epoch 258;    Neuron [6, 3];    	Sigma: 4.6678;    alpha: 0.5601
# Epoch 259;    Neuron [8, 6];    	Sigma: 4.6629;    alpha: 0.5596
# Epoch 260;    Neuron [4, 9];    	Sigma: 4.6581;    alpha: 0.5590
# Epoch 261;    Neuron [1, 8];    	Sigma: 4.6531;    alpha: 0.5584
# Epoch 262;    Neuron [9, 2];    	Sigma: 4.6482;    alpha: 0.5578
# Epoch 263;    Neuron [6, 3];    	Sigma: 4.6431;    alpha: 0.5572
# Epoch 264;    Neuron [9, 5];    	Sigma: 4.6381;    alpha: 0.5566
# Epoch 265;    Neuron [4, 5];    	Sigma: 4.6330;    alpha: 0.5560
# Epoch 266;    Neuron [4, 9];    	Sigma: 4.6278;    alpha: 0.5553
# Epoch 267;    Neuron [7, 2];    	Sigma: 4.6226;    alpha: 0.5547
# Epoch 268;    Neuron [2, 9];    	Sigma: 4.6174;    alpha: 0.5541
# Epoch 269;    Neuron [7, 5];    	Sigma: 4.6121;    alpha: 0.5534
# Epoch 270;    Neuron [5, 1];    	Sigma: 4.6067;    alpha: 0.5528
# Epoch 271;    Neuron [4, 7];    	Sigma: 4.6013;    alpha: 0.5522
# Epoch 272;    Neuron [2, 8];    	Sigma: 4.5959;    alpha: 0.5515
# Epoch 273;    Neuron [9, 4];    	Sigma: 4.5904;    alpha: 0.5508
# Epoch 274;    Neuron [1, 3];    	Sigma: 4.5849;    alpha: 0.5502
# Epoch 275;    Neuron [7, 7];    	Sigma: 4.5793;    alpha: 0.5495
# Epoch 276;    Neuron [9, 0];    	Sigma: 4.5737;    alpha: 0.5488
# Epoch 277;    Neuron [9, 4];    	Sigma: 4.5680;    alpha: 0.5482
# Epoch 278;    Neuron [3, 8];    	Sigma: 4.5623;    alpha: 0.5475
# Epoch 279;    Neuron [5, 7];    	Sigma: 4.5565;    alpha: 0.5468
# Epoch 280;    Neuron [5, 5];    	Sigma: 4.5507;    alpha: 0.5461
# Epoch 281;    Neuron [2, 5];    	Sigma: 4.5448;    alpha: 0.5454
# Epoch 282;    Neuron [5, 0];    	Sigma: 4.5389;    alpha: 0.5447
# Epoch 283;    Neuron [0, 3];    	Sigma: 4.5329;    alpha: 0.5440
# Epoch 284;    Neuron [3, 8];    	Sigma: 4.5269;    alpha: 0.5432
# Epoch 285;    Neuron [9, 8];    	Sigma: 4.5209;    alpha: 0.5425
# Epoch 286;    Neuron [8, 2];    	Sigma: 4.5148;    alpha: 0.5418
# Epoch 287;    Neuron [4, 4];    	Sigma: 4.5086;    alpha: 0.5410
# Epoch 288;    Neuron [5, 0];    	Sigma: 4.5024;    alpha: 0.5403
# Epoch 289;    Neuron [6, 5];    	Sigma: 4.4962;    alpha: 0.5395
# Epoch 290;    Neuron [8, 8];    	Sigma: 4.4899;    alpha: 0.5388
# Epoch 291;    Neuron [9, 3];    	Sigma: 4.4835;    alpha: 0.5380
# Epoch 292;    Neuron [5, 6];    	Sigma: 4.4771;    alpha: 0.5373
# Epoch 293;    Neuron [3, 0];    	Sigma: 4.4707;    alpha: 0.5365
# Epoch 294;    Neuron [2, 8];    	Sigma: 4.4642;    alpha: 0.5357
# Epoch 295;    Neuron [2, 6];    	Sigma: 4.4577;    alpha: 0.5349
# Epoch 296;    Neuron [9, 3];    	Sigma: 4.4511;    alpha: 0.5341
# Epoch 297;    Neuron [4, 1];    	Sigma: 4.4445;    alpha: 0.5333
# Epoch 298;    Neuron [7, 8];    	Sigma: 4.4378;    alpha: 0.5325
# Epoch 299;    Neuron [0, 2];    	Sigma: 4.4311;    alpha: 0.5317
# Epoch 300;    Neuron [4, 7];    	Sigma: 4.4243;    alpha: 0.5309
# Epoch 301;    Neuron [8, 3];    	Sigma: 4.4175;    alpha: 0.5301
# Epoch 302;    Neuron [6, 7];    	Sigma: 4.4106;    alpha: 0.5293
# Epoch 303;    Neuron [0, 1];    	Sigma: 4.4037;    alpha: 0.5284
# Epoch 304;    Neuron [8, 0];    	Sigma: 4.3968;    alpha: 0.5276
# Epoch 305;    Neuron [1, 4];    	Sigma: 4.3898;    alpha: 0.5268
# Epoch 306;    Neuron [8, 3];    	Sigma: 4.3827;    alpha: 0.5259
# Epoch 307;    Neuron [4, 6];    	Sigma: 4.3756;    alpha: 0.5251
# Epoch 308;    Neuron [9, 0];    	Sigma: 4.3685;    alpha: 0.5242
# Epoch 309;    Neuron [4, 1];    	Sigma: 4.3613;    alpha: 0.5234
# Epoch 310;    Neuron [1, 4];    	Sigma: 4.3541;    alpha: 0.5225
# Epoch 311;    Neuron [2, 2];    	Sigma: 4.3468;    alpha: 0.5216
# Epoch 312;    Neuron [7, 1];    	Sigma: 4.3394;    alpha: 0.5207
# Epoch 313;    Neuron [9, 4];    	Sigma: 4.3321;    alpha: 0.5198
# Epoch 314;    Neuron [2, 3];    	Sigma: 4.3247;    alpha: 0.5190
# Epoch 315;    Neuron [5, 9];    	Sigma: 4.3172;    alpha: 0.5181
# Epoch 316;    Neuron [6, 6];    	Sigma: 4.3097;    alpha: 0.5172
# Epoch 317;    Neuron [7, 2];    	Sigma: 4.3021;    alpha: 0.5163
# Epoch 318;    Neuron [9, 8];    	Sigma: 4.2945;    alpha: 0.5153
# Epoch 319;    Neuron [4, 4];    	Sigma: 4.2869;    alpha: 0.5144
# Epoch 320;    Neuron [5, 6];    	Sigma: 4.2792;    alpha: 0.5135
# Epoch 321;    Neuron [6, 7];    	Sigma: 4.2715;    alpha: 0.5126
# Epoch 322;    Neuron [4, 6];    	Sigma: 4.2637;    alpha: 0.5116
# Epoch 323;    Neuron [5, 9];    	Sigma: 4.2559;    alpha: 0.5107
# Epoch 324;    Neuron [7, 7];    	Sigma: 4.2480;    alpha: 0.5098
# Epoch 325;    Neuron [1, 2];    	Sigma: 4.2401;    alpha: 0.5088
# Epoch 326;    Neuron [6, 6];    	Sigma: 4.2321;    alpha: 0.5079
# Epoch 327;    Neuron [0, 9];    	Sigma: 4.2241;    alpha: 0.5069
# Epoch 328;    Neuron [5, 8];    	Sigma: 4.2161;    alpha: 0.5059
# Epoch 329;    Neuron [6, 4];    	Sigma: 4.2080;    alpha: 0.5050
# Epoch 330;    Neuron [9, 6];    	Sigma: 4.1999;    alpha: 0.5040
# Epoch 331;    Neuron [4, 5];    	Sigma: 4.1917;    alpha: 0.5030
# Epoch 332;    Neuron [0, 1];    	Sigma: 4.1835;    alpha: 0.5020
# Epoch 333;    Neuron [2, 7];    	Sigma: 4.1753;    alpha: 0.5010
# Epoch 334;    Neuron [3, 9];    	Sigma: 4.1670;    alpha: 0.5000
# Epoch 335;    Neuron [6, 0];    	Sigma: 4.1586;    alpha: 0.4990
# Epoch 336;    Neuron [8, 5];    	Sigma: 4.1503;    alpha: 0.4980
# Epoch 337;    Neuron [4, 8];    	Sigma: 4.1418;    alpha: 0.4970
# Epoch 338;    Neuron [1, 6];    	Sigma: 4.1334;    alpha: 0.4960
# Epoch 339;    Neuron [4, 3];    	Sigma: 4.1249;    alpha: 0.4950
# Epoch 340;    Neuron [7, 0];    	Sigma: 4.1163;    alpha: 0.4940
# Epoch 341;    Neuron [3, 1];    	Sigma: 4.1078;    alpha: 0.4929
# Epoch 342;    Neuron [4, 4];    	Sigma: 4.0991;    alpha: 0.4919
# Epoch 343;    Neuron [7, 3];    	Sigma: 4.0905;    alpha: 0.4909
# Epoch 344;    Neuron [6, 7];    	Sigma: 4.0818;    alpha: 0.4898
# Epoch 345;    Neuron [0, 2];    	Sigma: 4.0731;    alpha: 0.4888
# Epoch 346;    Neuron [0, 1];    	Sigma: 4.0643;    alpha: 0.4877
# Epoch 347;    Neuron [6, 7];    	Sigma: 4.0555;    alpha: 0.4867
# Epoch 348;    Neuron [1, 3];    	Sigma: 4.0466;    alpha: 0.4856
# Epoch 349;    Neuron [3, 7];    	Sigma: 4.0377;    alpha: 0.4845
# Epoch 350;    Neuron [1, 9];    	Sigma: 4.0288;    alpha: 0.4835
# Epoch 351;    Neuron [8, 5];    	Sigma: 4.0198;    alpha: 0.4824
# Epoch 352;    Neuron [0, 1];    	Sigma: 4.0108;    alpha: 0.4813
# Epoch 353;    Neuron [6, 4];    	Sigma: 4.0018;    alpha: 0.4802
# Epoch 354;    Neuron [9, 9];    	Sigma: 3.9927;    alpha: 0.4791
# Epoch 355;    Neuron [5, 0];    	Sigma: 3.9836;    alpha: 0.4780
# Epoch 356;    Neuron [7, 6];    	Sigma: 3.9745;    alpha: 0.4769
# Epoch 357;    Neuron [2, 6];    	Sigma: 3.9653;    alpha: 0.4758
# Epoch 358;    Neuron [0, 2];    	Sigma: 3.9561;    alpha: 0.4747
# Epoch 359;    Neuron [1, 1];    	Sigma: 3.9469;    alpha: 0.4736
# Epoch 360;    Neuron [9, 7];    	Sigma: 3.9376;    alpha: 0.4725
# Epoch 361;    Neuron [0, 0];    	Sigma: 3.9283;    alpha: 0.4714
# Epoch 362;    Neuron [5, 4];    	Sigma: 3.9189;    alpha: 0.4703
# Epoch 363;    Neuron [9, 2];    	Sigma: 3.9095;    alpha: 0.4691
# Epoch 364;    Neuron [0, 2];    	Sigma: 3.9001;    alpha: 0.4680
# Epoch 365;    Neuron [4, 7];    	Sigma: 3.8907;    alpha: 0.4669
# Epoch 366;    Neuron [8, 0];    	Sigma: 3.8812;    alpha: 0.4657
# Epoch 367;    Neuron [2, 3];    	Sigma: 3.8717;    alpha: 0.4646
# Epoch 368;    Neuron [2, 3];    	Sigma: 3.8622;    alpha: 0.4635
# Epoch 369;    Neuron [4, 1];    	Sigma: 3.8526;    alpha: 0.4623
# Epoch 370;    Neuron [6, 6];    	Sigma: 3.8430;    alpha: 0.4612
# Epoch 371;    Neuron [5, 8];    	Sigma: 3.8334;    alpha: 0.4600
# Epoch 372;    Neuron [3, 6];    	Sigma: 3.8237;    alpha: 0.4588
# Epoch 373;    Neuron [1, 1];    	Sigma: 3.8140;    alpha: 0.4577
# Epoch 374;    Neuron [4, 5];    	Sigma: 3.8043;    alpha: 0.4565
# Epoch 375;    Neuron [9, 4];    	Sigma: 3.7946;    alpha: 0.4553
# Epoch 376;    Neuron [9, 2];    	Sigma: 3.7848;    alpha: 0.4542
# Epoch 377;    Neuron [7, 5];    	Sigma: 3.7750;    alpha: 0.4530
# Epoch 378;    Neuron [5, 8];    	Sigma: 3.7652;    alpha: 0.4518
# Epoch 379;    Neuron [2, 6];    	Sigma: 3.7553;    alpha: 0.4506
# Epoch 380;    Neuron [1, 2];    	Sigma: 3.7454;    alpha: 0.4495
# Epoch 381;    Neuron [3, 9];    	Sigma: 3.7355;    alpha: 0.4483
# Epoch 382;    Neuron [0, 0];    	Sigma: 3.7256;    alpha: 0.4471
# Epoch 383;    Neuron [8, 1];    	Sigma: 3.7156;    alpha: 0.4459
# Epoch 384;    Neuron [8, 2];    	Sigma: 3.7057;    alpha: 0.4447
# Epoch 385;    Neuron [6, 7];    	Sigma: 3.6957;    alpha: 0.4435
# Epoch 386;    Neuron [4, 8];    	Sigma: 3.6856;    alpha: 0.4423
# Epoch 387;    Neuron [6, 5];    	Sigma: 3.6756;    alpha: 0.4411
# Epoch 388;    Neuron [0, 9];    	Sigma: 3.6655;    alpha: 0.4399
# Epoch 389;    Neuron [3, 5];    	Sigma: 3.6554;    alpha: 0.4386
# Epoch 390;    Neuron [2, 1];    	Sigma: 3.6453;    alpha: 0.4374
# Epoch 391;    Neuron [8, 0];    	Sigma: 3.6351;    alpha: 0.4362
# Epoch 392;    Neuron [9, 3];    	Sigma: 3.6250;    alpha: 0.4350
# Epoch 393;    Neuron [4, 9];    	Sigma: 3.6148;    alpha: 0.4338
# Epoch 394;    Neuron [6, 7];    	Sigma: 3.6046;    alpha: 0.4326
# Epoch 395;    Neuron [5, 8];    	Sigma: 3.5944;    alpha: 0.4313
# Epoch 396;    Neuron [0, 0];    	Sigma: 3.5841;    alpha: 0.4301
# Epoch 397;    Neuron [7, 2];    	Sigma: 3.5739;    alpha: 0.4289
# Epoch 398;    Neuron [2, 3];    	Sigma: 3.5636;    alpha: 0.4276
# Epoch 399;    Neuron [9, 1];    	Sigma: 3.5533;    alpha: 0.4264
# Epoch 400;    Neuron [2, 7];    	Sigma: 3.5430;    alpha: 0.4252
# Epoch 401;    Neuron [4, 5];    	Sigma: 3.5326;    alpha: 0.4239
# Epoch 402;    Neuron [6, 5];    	Sigma: 3.5223;    alpha: 0.4227
# Epoch 403;    Neuron [6, 9];    	Sigma: 3.5119;    alpha: 0.4214
# Epoch 404;    Neuron [6, 3];    	Sigma: 3.5015;    alpha: 0.4202
# Epoch 405;    Neuron [6, 6];    	Sigma: 3.4911;    alpha: 0.4189
# Epoch 406;    Neuron [1, 2];    	Sigma: 3.4807;    alpha: 0.4177
# Epoch 407;    Neuron [9, 4];    	Sigma: 3.4703;    alpha: 0.4164
# Epoch 408;    Neuron [1, 6];    	Sigma: 3.4599;    alpha: 0.4152
# Epoch 409;    Neuron [5, 8];    	Sigma: 3.4494;    alpha: 0.4139
# Epoch 410;    Neuron [7, 7];    	Sigma: 3.4389;    alpha: 0.4127
# Epoch 411;    Neuron [4, 6];    	Sigma: 3.4285;    alpha: 0.4114
# Epoch 412;    Neuron [2, 1];    	Sigma: 3.4180;    alpha: 0.4102
# Epoch 413;    Neuron [8, 6];    	Sigma: 3.4075;    alpha: 0.4089
# Epoch 414;    Neuron [9, 0];    	Sigma: 3.3969;    alpha: 0.4076
# Epoch 415;    Neuron [5, 5];    	Sigma: 3.3864;    alpha: 0.4064
# Epoch 416;    Neuron [3, 7];    	Sigma: 3.3759;    alpha: 0.4051
# Epoch 417;    Neuron [4, 4];    	Sigma: 3.3653;    alpha: 0.4038
# Epoch 418;    Neuron [0, 9];    	Sigma: 3.3548;    alpha: 0.4026
# Epoch 419;    Neuron [0, 2];    	Sigma: 3.3442;    alpha: 0.4013
# Epoch 420;    Neuron [1, 6];    	Sigma: 3.3336;    alpha: 0.4000
# Epoch 421;    Neuron [3, 0];    	Sigma: 3.3230;    alpha: 0.3988
# Epoch 422;    Neuron [8, 5];    	Sigma: 3.3124;    alpha: 0.3975
# Epoch 423;    Neuron [8, 1];    	Sigma: 3.3018;    alpha: 0.3962
# Epoch 424;    Neuron [1, 2];    	Sigma: 3.2912;    alpha: 0.3949
# Epoch 425;    Neuron [5, 8];    	Sigma: 3.2806;    alpha: 0.3937
# Epoch 426;    Neuron [5, 6];    	Sigma: 3.2700;    alpha: 0.3924
# Epoch 427;    Neuron [0, 9];    	Sigma: 3.2594;    alpha: 0.3911
# Epoch 428;    Neuron [6, 1];    	Sigma: 3.2487;    alpha: 0.3898
# Epoch 429;    Neuron [7, 8];    	Sigma: 3.2381;    alpha: 0.3886
# Epoch 430;    Neuron [7, 6];    	Sigma: 3.2275;    alpha: 0.3873
# Epoch 431;    Neuron [2, 1];    	Sigma: 3.2168;    alpha: 0.3860
# Epoch 432;    Neuron [9, 1];    	Sigma: 3.2062;    alpha: 0.3847
# Epoch 433;    Neuron [6, 4];    	Sigma: 3.1955;    alpha: 0.3835
# Epoch 434;    Neuron [3, 7];    	Sigma: 3.1849;    alpha: 0.3822
# Epoch 435;    Neuron [3, 5];    	Sigma: 3.1742;    alpha: 0.3809
# Epoch 436;    Neuron [3, 8];    	Sigma: 3.1636;    alpha: 0.3796
# Epoch 437;    Neuron [5, 0];    	Sigma: 3.1529;    alpha: 0.3783
# Epoch 438;    Neuron [1, 8];    	Sigma: 3.1422;    alpha: 0.3771
# Epoch 439;    Neuron [0, 3];    	Sigma: 3.1316;    alpha: 0.3758
# Epoch 440;    Neuron [1, 6];    	Sigma: 3.1209;    alpha: 0.3745
# Epoch 441;    Neuron [9, 3];    	Sigma: 3.1102;    alpha: 0.3732
# Epoch 442;    Neuron [0, 2];    	Sigma: 3.0996;    alpha: 0.3719
# Epoch 443;    Neuron [4, 5];    	Sigma: 3.0889;    alpha: 0.3707
# Epoch 444;    Neuron [4, 8];    	Sigma: 3.0783;    alpha: 0.3694
# Epoch 445;    Neuron [9, 0];    	Sigma: 3.0676;    alpha: 0.3681
# Epoch 446;    Neuron [2, 0];    	Sigma: 3.0569;    alpha: 0.3668
# Epoch 447;    Neuron [5, 9];    	Sigma: 3.0463;    alpha: 0.3656
# Epoch 448;    Neuron [5, 2];    	Sigma: 3.0356;    alpha: 0.3643
# Epoch 449;    Neuron [7, 6];    	Sigma: 3.0250;    alpha: 0.3630
# Epoch 450;    Neuron [1, 3];    	Sigma: 3.0144;    alpha: 0.3617
# Epoch 451;    Neuron [5, 3];    	Sigma: 3.0037;    alpha: 0.3604
# Epoch 452;    Neuron [3, 6];    	Sigma: 2.9931;    alpha: 0.3592
# Epoch 453;    Neuron [8, 1];    	Sigma: 2.9825;    alpha: 0.3579
# Epoch 454;    Neuron [5, 5];    	Sigma: 2.9718;    alpha: 0.3566
# Epoch 455;    Neuron [0, 0];    	Sigma: 2.9612;    alpha: 0.3553
# Epoch 456;    Neuron [5, 8];    	Sigma: 2.9506;    alpha: 0.3541
# Epoch 457;    Neuron [3, 4];    	Sigma: 2.9400;    alpha: 0.3528
# Epoch 458;    Neuron [7, 1];    	Sigma: 2.9294;    alpha: 0.3515
# Epoch 459;    Neuron [2, 6];    	Sigma: 2.9188;    alpha: 0.3503
# Epoch 460;    Neuron [7, 5];    	Sigma: 2.9082;    alpha: 0.3490
# Epoch 461;    Neuron [4, 3];    	Sigma: 2.8976;    alpha: 0.3477
# Epoch 462;    Neuron [0, 2];    	Sigma: 2.8871;    alpha: 0.3464
# Epoch 463;    Neuron [7, 8];    	Sigma: 2.8765;    alpha: 0.3452
# Epoch 464;    Neuron [1, 9];    	Sigma: 2.8660;    alpha: 0.3439
# Epoch 465;    Neuron [7, 8];    	Sigma: 2.8554;    alpha: 0.3427
# Epoch 466;    Neuron [7, 3];    	Sigma: 2.8449;    alpha: 0.3414
# Epoch 467;    Neuron [1, 1];    	Sigma: 2.8344;    alpha: 0.3401
# Epoch 468;    Neuron [6, 4];    	Sigma: 2.8239;    alpha: 0.3389
# Epoch 469;    Neuron [0, 9];    	Sigma: 2.8134;    alpha: 0.3376
# Epoch 470;    Neuron [8, 1];    	Sigma: 2.8029;    alpha: 0.3363
# Epoch 471;    Neuron [9, 3];    	Sigma: 2.7924;    alpha: 0.3351
# Epoch 472;    Neuron [1, 0];    	Sigma: 2.7819;    alpha: 0.3338
# Epoch 473;    Neuron [0, 2];    	Sigma: 2.7715;    alpha: 0.3326
# Epoch 474;    Neuron [9, 0];    	Sigma: 2.7610;    alpha: 0.3313
# Epoch 475;    Neuron [9, 6];    	Sigma: 2.7506;    alpha: 0.3301
# Epoch 476;    Neuron [7, 5];    	Sigma: 2.7402;    alpha: 0.3288
# Epoch 477;    Neuron [3, 0];    	Sigma: 2.7298;    alpha: 0.3276
# Epoch 478;    Neuron [9, 9];    	Sigma: 2.7194;    alpha: 0.3263
# Epoch 479;    Neuron [3, 5];    	Sigma: 2.7090;    alpha: 0.3251
# Epoch 480;    Neuron [1, 9];    	Sigma: 2.6987;    alpha: 0.3238
# Epoch 481;    Neuron [2, 0];    	Sigma: 2.6883;    alpha: 0.3226
# Epoch 482;    Neuron [5, 2];    	Sigma: 2.6780;    alpha: 0.3214
# Epoch 483;    Neuron [8, 8];    	Sigma: 2.6677;    alpha: 0.3201
# Epoch 484;    Neuron [2, 2];    	Sigma: 2.6574;    alpha: 0.3189
# Epoch 485;    Neuron [2, 6];    	Sigma: 2.6471;    alpha: 0.3177
# Epoch 486;    Neuron [1, 7];    	Sigma: 2.6369;    alpha: 0.3164
# Epoch 487;    Neuron [6, 6];    	Sigma: 2.6266;    alpha: 0.3152
# Epoch 488;    Neuron [2, 9];    	Sigma: 2.6164;    alpha: 0.3140
# Epoch 489;    Neuron [3, 9];    	Sigma: 2.6062;    alpha: 0.3127
# Epoch 490;    Neuron [5, 5];    	Sigma: 2.5960;    alpha: 0.3115
# Epoch 491;    Neuron [6, 8];    	Sigma: 2.5858;    alpha: 0.3103
# Epoch 492;    Neuron [4, 6];    	Sigma: 2.5756;    alpha: 0.3091
# Epoch 493;    Neuron [5, 8];    	Sigma: 2.5655;    alpha: 0.3079
# Epoch 494;    Neuron [1, 1];    	Sigma: 2.5554;    alpha: 0.3066
# Epoch 495;    Neuron [8, 1];    	Sigma: 2.5452;    alpha: 0.3054
# Epoch 496;    Neuron [3, 7];    	Sigma: 2.5352;    alpha: 0.3042
# Epoch 497;    Neuron [3, 8];    	Sigma: 2.5251;    alpha: 0.3030
# Epoch 498;    Neuron [0, 0];    	Sigma: 2.5150;    alpha: 0.3018
# Epoch 499;    Neuron [2, 0];    	Sigma: 2.5050;    alpha: 0.3006
# Epoch 500;    Neuron [0, 8];    	Sigma: 2.4950;    alpha: 0.2994
# Epoch 501;    Neuron [6, 6];    	Sigma: 2.4850;    alpha: 0.2982
# Epoch 502;    Neuron [4, 3];    	Sigma: 2.4750;    alpha: 0.2970
# Epoch 503;    Neuron [7, 6];    	Sigma: 2.4651;    alpha: 0.2958
# Epoch 504;    Neuron [5, 4];    	Sigma: 2.4552;    alpha: 0.2946
# Epoch 505;    Neuron [9, 2];    	Sigma: 2.4453;    alpha: 0.2934
# Epoch 506;    Neuron [5, 9];    	Sigma: 2.4354;    alpha: 0.2922
# Epoch 507;    Neuron [9, 3];    	Sigma: 2.4255;    alpha: 0.2911
# Epoch 508;    Neuron [7, 5];    	Sigma: 2.4157;    alpha: 0.2899
# Epoch 509;    Neuron [0, 3];    	Sigma: 2.4058;    alpha: 0.2887
# Epoch 510;    Neuron [8, 6];    	Sigma: 2.3960;    alpha: 0.2875
# Epoch 511;    Neuron [1, 2];    	Sigma: 2.3863;    alpha: 0.2864
# Epoch 512;    Neuron [9, 1];    	Sigma: 2.3765;    alpha: 0.2852
# Epoch 513;    Neuron [0, 6];    	Sigma: 2.3668;    alpha: 0.2840
# Epoch 514;    Neuron [8, 2];    	Sigma: 2.3571;    alpha: 0.2828
# Epoch 515;    Neuron [2, 2];    	Sigma: 2.3474;    alpha: 0.2817
# Epoch 516;    Neuron [4, 6];    	Sigma: 2.3377;    alpha: 0.2805
# Epoch 517;    Neuron [9, 1];    	Sigma: 2.3281;    alpha: 0.2794
# Epoch 518;    Neuron [3, 1];    	Sigma: 2.3185;    alpha: 0.2782
# Epoch 519;    Neuron [1, 2];    	Sigma: 2.3089;    alpha: 0.2771
# Epoch 520;    Neuron [7, 6];    	Sigma: 2.2993;    alpha: 0.2759
# Epoch 521;    Neuron [0, 3];    	Sigma: 2.2898;    alpha: 0.2748
# Epoch 522;    Neuron [6, 4];    	Sigma: 2.2803;    alpha: 0.2736
# Epoch 523;    Neuron [6, 7];    	Sigma: 2.2708;    alpha: 0.2725
# Epoch 524;    Neuron [2, 2];    	Sigma: 2.2613;    alpha: 0.2714
# Epoch 525;    Neuron [5, 5];    	Sigma: 2.2519;    alpha: 0.2702
# Epoch 526;    Neuron [5, 7];    	Sigma: 2.2424;    alpha: 0.2691
# Epoch 527;    Neuron [3, 5];    	Sigma: 2.2331;    alpha: 0.2680
# Epoch 528;    Neuron [9, 0];    	Sigma: 2.2237;    alpha: 0.2668
# Epoch 529;    Neuron [7, 8];    	Sigma: 2.2143;    alpha: 0.2657
# Epoch 530;    Neuron [0, 9];    	Sigma: 2.2050;    alpha: 0.2646
# Epoch 531;    Neuron [7, 6];    	Sigma: 2.1957;    alpha: 0.2635
# Epoch 532;    Neuron [9, 4];    	Sigma: 2.1865;    alpha: 0.2624
# Epoch 533;    Neuron [8, 7];    	Sigma: 2.1772;    alpha: 0.2613
# Epoch 534;    Neuron [7, 6];    	Sigma: 2.1680;    alpha: 0.2602
# Epoch 535;    Neuron [3, 5];    	Sigma: 2.1588;    alpha: 0.2591
# Epoch 536;    Neuron [2, 8];    	Sigma: 2.1497;    alpha: 0.2580
# Epoch 537;    Neuron [5, 4];    	Sigma: 2.1406;    alpha: 0.2569
# Epoch 538;    Neuron [0, 5];    	Sigma: 2.1315;    alpha: 0.2558
# Epoch 539;    Neuron [4, 6];    	Sigma: 2.1224;    alpha: 0.2547
# Epoch 540;    Neuron [3, 4];    	Sigma: 2.1133;    alpha: 0.2536
# Epoch 541;    Neuron [9, 2];    	Sigma: 2.1043;    alpha: 0.2525
# Epoch 542;    Neuron [1, 3];    	Sigma: 2.0953;    alpha: 0.2514
# Epoch 543;    Neuron [2, 5];    	Sigma: 2.0863;    alpha: 0.2504
# Epoch 544;    Neuron [2, 0];    	Sigma: 2.0774;    alpha: 0.2493
# Epoch 545;    Neuron [9, 6];    	Sigma: 2.0685;    alpha: 0.2482
# Epoch 546;    Neuron [1, 3];    	Sigma: 2.0596;    alpha: 0.2472
# Epoch 547;    Neuron [9, 6];    	Sigma: 2.0507;    alpha: 0.2461
# Epoch 548;    Neuron [1, 1];    	Sigma: 2.0419;    alpha: 0.2450
# Epoch 549;    Neuron [8, 7];    	Sigma: 2.0331;    alpha: 0.2440
# Epoch 550;    Neuron [3, 1];    	Sigma: 2.0243;    alpha: 0.2429
# Epoch 551;    Neuron [7, 6];    	Sigma: 2.0156;    alpha: 0.2419
# Epoch 552;    Neuron [3, 7];    	Sigma: 2.0068;    alpha: 0.2408
# Epoch 553;    Neuron [1, 9];    	Sigma: 1.9982;    alpha: 0.2398
# Epoch 554;    Neuron [0, 9];    	Sigma: 1.9895;    alpha: 0.2387
# Epoch 555;    Neuron [3, 0];    	Sigma: 1.9809;    alpha: 0.2377
# Epoch 556;    Neuron [3, 9];    	Sigma: 1.9723;    alpha: 0.2367
# Epoch 557;    Neuron [6, 7];    	Sigma: 1.9637;    alpha: 0.2356
# Epoch 558;    Neuron [3, 5];    	Sigma: 1.9551;    alpha: 0.2346
# Epoch 559;    Neuron [0, 1];    	Sigma: 1.9466;    alpha: 0.2336
# Epoch 560;    Neuron [9, 0];    	Sigma: 1.9381;    alpha: 0.2326
# Epoch 561;    Neuron [8, 0];    	Sigma: 1.9296;    alpha: 0.2316
# Epoch 562;    Neuron [7, 4];    	Sigma: 1.9212;    alpha: 0.2305
# Epoch 563;    Neuron [3, 7];    	Sigma: 1.9128;    alpha: 0.2295
# Epoch 564;    Neuron [4, 5];    	Sigma: 1.9044;    alpha: 0.2285
# Epoch 565;    Neuron [6, 8];    	Sigma: 1.8961;    alpha: 0.2275
# Epoch 566;    Neuron [2, 2];    	Sigma: 1.8878;    alpha: 0.2265
# Epoch 567;    Neuron [7, 1];    	Sigma: 1.8795;    alpha: 0.2255
# Epoch 568;    Neuron [8, 0];    	Sigma: 1.8712;    alpha: 0.2245
# Epoch 569;    Neuron [5, 3];    	Sigma: 1.8630;    alpha: 0.2236
# Epoch 570;    Neuron [3, 1];    	Sigma: 1.8548;    alpha: 0.2226
# Epoch 571;    Neuron [1, 0];    	Sigma: 1.8466;    alpha: 0.2216
# Epoch 572;    Neuron [0, 8];    	Sigma: 1.8385;    alpha: 0.2206
# Epoch 573;    Neuron [6, 4];    	Sigma: 1.8304;    alpha: 0.2196
# Epoch 574;    Neuron [4, 1];    	Sigma: 1.8223;    alpha: 0.2187
# Epoch 575;    Neuron [9, 6];    	Sigma: 1.8142;    alpha: 0.2177
# Epoch 576;    Neuron [4, 4];    	Sigma: 1.8062;    alpha: 0.2167
# Epoch 577;    Neuron [0, 4];    	Sigma: 1.7982;    alpha: 0.2158
# Epoch 578;    Neuron [6, 3];    	Sigma: 1.7902;    alpha: 0.2148
# Epoch 579;    Neuron [6, 6];    	Sigma: 1.7823;    alpha: 0.2139
# Epoch 580;    Neuron [7, 7];    	Sigma: 1.7744;    alpha: 0.2129
# Epoch 581;    Neuron [2, 2];    	Sigma: 1.7665;    alpha: 0.2120
# Epoch 582;    Neuron [5, 6];    	Sigma: 1.7586;    alpha: 0.2110
# Epoch 583;    Neuron [7, 4];    	Sigma: 1.7508;    alpha: 0.2101
# Epoch 584;    Neuron [6, 5];    	Sigma: 1.7430;    alpha: 0.2092
# Epoch 585;    Neuron [1, 2];    	Sigma: 1.7353;    alpha: 0.2082
# Epoch 586;    Neuron [1, 6];    	Sigma: 1.7275;    alpha: 0.2073
# Epoch 587;    Neuron [4, 2];    	Sigma: 1.7198;    alpha: 0.2064
# Epoch 588;    Neuron [9, 1];    	Sigma: 1.7122;    alpha: 0.2055
# Epoch 589;    Neuron [2, 1];    	Sigma: 1.7045;    alpha: 0.2045
# Epoch 590;    Neuron [9, 1];    	Sigma: 1.6969;    alpha: 0.2036
# Epoch 591;    Neuron [1, 9];    	Sigma: 1.6893;    alpha: 0.2027
# Epoch 592;    Neuron [3, 2];    	Sigma: 1.6818;    alpha: 0.2018
# Epoch 593;    Neuron [3, 1];    	Sigma: 1.6742;    alpha: 0.2009
# Epoch 594;    Neuron [2, 0];    	Sigma: 1.6667;    alpha: 0.2000
# Epoch 595;    Neuron [1, 7];    	Sigma: 1.6593;    alpha: 0.1991
# Epoch 596;    Neuron [5, 3];    	Sigma: 1.6518;    alpha: 0.1982
# Epoch 597;    Neuron [8, 7];    	Sigma: 1.6444;    alpha: 0.1973
# Epoch 598;    Neuron [5, 5];    	Sigma: 1.6370;    alpha: 0.1964
# Epoch 599;    Neuron [9, 9];    	Sigma: 1.6297;    alpha: 0.1956
# Epoch 600;    Neuron [1, 3];    	Sigma: 1.6224;    alpha: 0.1947
# Epoch 601;    Neuron [0, 2];    	Sigma: 1.6151;    alpha: 0.1938
# Epoch 602;    Neuron [9, 9];    	Sigma: 1.6078;    alpha: 0.1929
# Epoch 603;    Neuron [3, 4];    	Sigma: 1.6006;    alpha: 0.1921
# Epoch 604;    Neuron [6, 2];    	Sigma: 1.5934;    alpha: 0.1912
# Epoch 605;    Neuron [9, 6];    	Sigma: 1.5862;    alpha: 0.1903
# Epoch 606;    Neuron [5, 4];    	Sigma: 1.5791;    alpha: 0.1895
# Epoch 607;    Neuron [2, 3];    	Sigma: 1.5719;    alpha: 0.1886
# Epoch 608;    Neuron [8, 1];    	Sigma: 1.5649;    alpha: 0.1878
# Epoch 609;    Neuron [0, 2];    	Sigma: 1.5578;    alpha: 0.1869
# Epoch 610;    Neuron [7, 0];    	Sigma: 1.5508;    alpha: 0.1861
# Epoch 611;    Neuron [8, 1];    	Sigma: 1.5438;    alpha: 0.1853
# Epoch 612;    Neuron [3, 9];    	Sigma: 1.5368;    alpha: 0.1844
# Epoch 613;    Neuron [3, 6];    	Sigma: 1.5298;    alpha: 0.1836
# Epoch 614;    Neuron [8, 7];    	Sigma: 1.5229;    alpha: 0.1828
# Epoch 615;    Neuron [0, 9];    	Sigma: 1.5160;    alpha: 0.1819
# Epoch 616;    Neuron [6, 2];    	Sigma: 1.5092;    alpha: 0.1811
# Epoch 617;    Neuron [5, 2];    	Sigma: 1.5024;    alpha: 0.1803
# Epoch 618;    Neuron [0, 4];    	Sigma: 1.4956;    alpha: 0.1795
# Epoch 619;    Neuron [6, 5];    	Sigma: 1.4888;    alpha: 0.1787
# Epoch 620;    Neuron [9, 7];    	Sigma: 1.4821;    alpha: 0.1778
# Epoch 621;    Neuron [9, 5];    	Sigma: 1.4753;    alpha: 0.1770
# Epoch 622;    Neuron [6, 9];    	Sigma: 1.4687;    alpha: 0.1762
# Epoch 623;    Neuron [3, 8];    	Sigma: 1.4620;    alpha: 0.1754
# Epoch 624;    Neuron [9, 5];    	Sigma: 1.4554;    alpha: 0.1746
# Epoch 625;    Neuron [4, 5];    	Sigma: 1.4488;    alpha: 0.1739
# Epoch 626;    Neuron [3, 9];    	Sigma: 1.4422;    alpha: 0.1731
# Epoch 627;    Neuron [8, 1];    	Sigma: 1.4357;    alpha: 0.1723
# Epoch 628;    Neuron [7, 6];    	Sigma: 1.4291;    alpha: 0.1715
# Epoch 629;    Neuron [6, 5];    	Sigma: 1.4227;    alpha: 0.1707
# Epoch 630;    Neuron [4, 1];    	Sigma: 1.4162;    alpha: 0.1699
# Epoch 631;    Neuron [0, 8];    	Sigma: 1.4098;    alpha: 0.1692
# Epoch 632;    Neuron [2, 9];    	Sigma: 1.4034;    alpha: 0.1684
# Epoch 633;    Neuron [9, 9];    	Sigma: 1.3970;    alpha: 0.1676
# Epoch 634;    Neuron [5, 7];    	Sigma: 1.3906;    alpha: 0.1669
# Epoch 635;    Neuron [7, 5];    	Sigma: 1.3843;    alpha: 0.1661
# Epoch 636;    Neuron [0, 0];    	Sigma: 1.3780;    alpha: 0.1654
# Epoch 637;    Neuron [5, 4];    	Sigma: 1.3718;    alpha: 0.1646
# Epoch 638;    Neuron [3, 7];    	Sigma: 1.3655;    alpha: 0.1639
# Epoch 639;    Neuron [9, 9];    	Sigma: 1.3593;    alpha: 0.1631
# Epoch 640;    Neuron [1, 1];    	Sigma: 1.3531;    alpha: 0.1624
# Epoch 641;    Neuron [3, 0];    	Sigma: 1.3470;    alpha: 0.1616
# Epoch 642;    Neuron [0, 4];    	Sigma: 1.3409;    alpha: 0.1609
# Epoch 643;    Neuron [7, 5];    	Sigma: 1.3348;    alpha: 0.1602
# Epoch 644;    Neuron [5, 9];    	Sigma: 1.3287;    alpha: 0.1594
# Epoch 645;    Neuron [2, 2];    	Sigma: 1.3226;    alpha: 0.1587
# Epoch 646;    Neuron [9, 9];    	Sigma: 1.3166;    alpha: 0.1580
# Epoch 647;    Neuron [5, 9];    	Sigma: 1.3106;    alpha: 0.1573
# Epoch 648;    Neuron [1, 2];    	Sigma: 1.3047;    alpha: 0.1566
# Epoch 649;    Neuron [7, 5];    	Sigma: 1.2987;    alpha: 0.1558
# Epoch 650;    Neuron [6, 8];    	Sigma: 1.2928;    alpha: 0.1551
# Epoch 651;    Neuron [0, 3];    	Sigma: 1.2869;    alpha: 0.1544
# Epoch 652;    Neuron [3, 7];    	Sigma: 1.2811;    alpha: 0.1537
# Epoch 653;    Neuron [2, 6];    	Sigma: 1.2752;    alpha: 0.1530
# Epoch 654;    Neuron [7, 7];    	Sigma: 1.2694;    alpha: 0.1523
# Epoch 655;    Neuron [7, 1];    	Sigma: 1.2636;    alpha: 0.1516
# Epoch 656;    Neuron [3, 5];    	Sigma: 1.2579;    alpha: 0.1509
# Epoch 657;    Neuron [4, 5];    	Sigma: 1.2522;    alpha: 0.1503
# Epoch 658;    Neuron [5, 6];    	Sigma: 1.2465;    alpha: 0.1496
# Epoch 659;    Neuron [0, 9];    	Sigma: 1.2408;    alpha: 0.1489
# Epoch 660;    Neuron [9, 8];    	Sigma: 1.2351;    alpha: 0.1482
# Epoch 661;    Neuron [4, 6];    	Sigma: 1.2295;    alpha: 0.1475
# Epoch 662;    Neuron [0, 0];    	Sigma: 1.2239;    alpha: 0.1469
# Epoch 663;    Neuron [5, 4];    	Sigma: 1.2183;    alpha: 0.1462
# Epoch 664;    Neuron [0, 1];    	Sigma: 1.2128;    alpha: 0.1455
# Epoch 665;    Neuron [6, 9];    	Sigma: 1.2073;    alpha: 0.1449
# Epoch 666;    Neuron [4, 0];    	Sigma: 1.2018;    alpha: 0.1442
# Epoch 667;    Neuron [9, 2];    	Sigma: 1.1963;    alpha: 0.1436
# Epoch 668;    Neuron [3, 2];    	Sigma: 1.1909;    alpha: 0.1429
# Epoch 669;    Neuron [0, 1];    	Sigma: 1.1854;    alpha: 0.1423
# Epoch 670;    Neuron [2, 2];    	Sigma: 1.1801;    alpha: 0.1416
# Epoch 671;    Neuron [6, 6];    	Sigma: 1.1747;    alpha: 0.1410
# Epoch 672;    Neuron [7, 8];    	Sigma: 1.1693;    alpha: 0.1403
# Epoch 673;    Neuron [6, 7];    	Sigma: 1.1640;    alpha: 0.1397
# Epoch 674;    Neuron [7, 6];    	Sigma: 1.1587;    alpha: 0.1390
# Epoch 675;    Neuron [0, 8];    	Sigma: 1.1534;    alpha: 0.1384
# Epoch 676;    Neuron [7, 8];    	Sigma: 1.1482;    alpha: 0.1378
# Epoch 677;    Neuron [0, 3];    	Sigma: 1.1430;    alpha: 0.1372
# Epoch 678;    Neuron [2, 9];    	Sigma: 1.1378;    alpha: 0.1365
# Epoch 679;    Neuron [7, 1];    	Sigma: 1.1326;    alpha: 0.1359
# Epoch 680;    Neuron [5, 4];    	Sigma: 1.1275;    alpha: 0.1353
# Epoch 681;    Neuron [5, 6];    	Sigma: 1.1223;    alpha: 0.1347
# Epoch 682;    Neuron [5, 2];    	Sigma: 1.1172;    alpha: 0.1341
# Epoch 683;    Neuron [2, 6];    	Sigma: 1.1122;    alpha: 0.1335
# Epoch 684;    Neuron [9, 6];    	Sigma: 1.1071;    alpha: 0.1329
# Epoch 685;    Neuron [2, 5];    	Sigma: 1.1021;    alpha: 0.1322
# Epoch 686;    Neuron [1, 1];    	Sigma: 1.0971;    alpha: 0.1316
# Epoch 687;    Neuron [3, 4];    	Sigma: 1.0921;    alpha: 0.1311
# Epoch 688;    Neuron [6, 7];    	Sigma: 1.0871;    alpha: 0.1305
# Epoch 689;    Neuron [0, 2];    	Sigma: 1.0822;    alpha: 0.1299
# Epoch 690;    Neuron [9, 0];    	Sigma: 1.0773;    alpha: 0.1293
# Epoch 691;    Neuron [9, 8];    	Sigma: 1.0724;    alpha: 0.1287
# Epoch 692;    Neuron [0, 9];    	Sigma: 1.0675;    alpha: 0.1281
# Epoch 693;    Neuron [1, 2];    	Sigma: 1.0627;    alpha: 0.1275
# Epoch 694;    Neuron [7, 7];    	Sigma: 1.0579;    alpha: 0.1269
# Epoch 695;    Neuron [3, 9];    	Sigma: 1.0531;    alpha: 0.1264
# Epoch 696;    Neuron [2, 2];    	Sigma: 1.0483;    alpha: 0.1258
# Epoch 697;    Neuron [1, 8];    	Sigma: 1.0436;    alpha: 0.1252
# Epoch 698;    Neuron [6, 6];    	Sigma: 1.0388;    alpha: 0.1247
# Epoch 699;    Neuron [1, 9];    	Sigma: 1.0341;    alpha: 0.1241
# Epoch 700;    Neuron [6, 7];    	Sigma: 1.0294;    alpha: 0.1235
# Epoch 701;    Neuron [6, 9];    	Sigma: 1.0248;    alpha: 0.1230
# Epoch 702;    Neuron [1, 5];    	Sigma: 1.0201;    alpha: 0.1224
# Epoch 703;    Neuron [5, 6];    	Sigma: 1.0155;    alpha: 0.1219
# Epoch 704;    Neuron [5, 5];    	Sigma: 1.0109;    alpha: 0.1213
# Epoch 705;    Neuron [1, 8];    	Sigma: 1.0064;    alpha: 0.1208
# Epoch 706;    Neuron [9, 0];    	Sigma: 1.0018;    alpha: 0.1202
# Epoch 707;    Neuron [6, 7];    	Sigma: 0.9973;    alpha: 0.1197
# Epoch 708;    Neuron [4, 7];    	Sigma: 0.9928;    alpha: 0.1191
# Epoch 709;    Neuron [2, 1];    	Sigma: 0.9883;    alpha: 0.1186
# Epoch 710;    Neuron [5, 7];    	Sigma: 0.9838;    alpha: 0.1181
# Epoch 711;    Neuron [0, 1];    	Sigma: 0.9794;    alpha: 0.1175
# Epoch 712;    Neuron [7, 4];    	Sigma: 0.9750;    alpha: 0.1170
# Epoch 713;    Neuron [1, 1];    	Sigma: 0.9706;    alpha: 0.1165
# Epoch 714;    Neuron [1, 6];    	Sigma: 0.9662;    alpha: 0.1159
# Epoch 715;    Neuron [6, 5];    	Sigma: 0.9618;    alpha: 0.1154
# Epoch 716;    Neuron [4, 8];    	Sigma: 0.9575;    alpha: 0.1149
# Epoch 717;    Neuron [3, 1];    	Sigma: 0.9532;    alpha: 0.1144
# Epoch 718;    Neuron [9, 2];    	Sigma: 0.9489;    alpha: 0.1139
# Epoch 719;    Neuron [3, 9];    	Sigma: 0.9446;    alpha: 0.1134
# Epoch 720;    Neuron [2, 8];    	Sigma: 0.9404;    alpha: 0.1128
# Epoch 721;    Neuron [6, 3];    	Sigma: 0.9361;    alpha: 0.1123
# Epoch 722;    Neuron [6, 9];    	Sigma: 0.9319;    alpha: 0.1118
# Epoch 723;    Neuron [8, 3];    	Sigma: 0.9277;    alpha: 0.1113
# Epoch 724;    Neuron [6, 9];    	Sigma: 0.9236;    alpha: 0.1108
# Epoch 725;    Neuron [1, 0];    	Sigma: 0.9194;    alpha: 0.1103
# Epoch 726;    Neuron [3, 0];    	Sigma: 0.9153;    alpha: 0.1098
# Epoch 727;    Neuron [6, 9];    	Sigma: 0.9112;    alpha: 0.1093
# Epoch 728;    Neuron [6, 3];    	Sigma: 0.9071;    alpha: 0.1089
# Epoch 729;    Neuron [5, 3];    	Sigma: 0.9030;    alpha: 0.1084
# Epoch 730;    Neuron [6, 9];    	Sigma: 0.8990;    alpha: 0.1079
# Epoch 731;    Neuron [5, 8];    	Sigma: 0.8949;    alpha: 0.1074
# Epoch 732;    Neuron [4, 4];    	Sigma: 0.8909;    alpha: 0.1069
# Epoch 733;    Neuron [7, 4];    	Sigma: 0.8869;    alpha: 0.1064
# Epoch 734;    Neuron [1, 1];    	Sigma: 0.8830;    alpha: 0.1060
# Epoch 735;    Neuron [0, 9];    	Sigma: 0.8790;    alpha: 0.1055
# Epoch 736;    Neuron [4, 1];    	Sigma: 0.8751;    alpha: 0.1050
# Epoch 737;    Neuron [6, 2];    	Sigma: 0.8712;    alpha: 0.1045
# Epoch 738;    Neuron [4, 7];    	Sigma: 0.8673;    alpha: 0.1041
# Epoch 739;    Neuron [4, 3];    	Sigma: 0.8634;    alpha: 0.1036
# ...
# Epoch 755;    Neuron [7, 7];    	Sigma: 0.8039;    alpha: 0.0965
# Epoch 756;    Neuron [6, 2];    	Sigma: 0.8003;    alpha: 0.0960
# Epoch 757;    Neuron [1, 1];    	Sigma: 0.7968;    alpha: 0.0956
# Epoch 758;    Neuron [4, 7];    	Sigma: 0.7933;    alpha: 0.0952
# Epoch 759;    Neuron [8, 3];    	Sigma: 0.7897;    alpha: 0.0948
# Epoch 760;    Neuron [2, 0];    	Sigma: 0.7862;    alpha: 0.0943
# Epoch 761;    Neuron [8, 8];    	Sigma: 0.7828;    alpha: 0.0939
# Epoch 762;    Neuron [6, 9];    	Sigma: 0.7793;    alpha: 0.0935
# Epoch 763;    Neuron [3, 3];    	Sigma: 0.7759;    alpha: 0.0931
# Epoch 764;    Neuron [0, 0];    	Sigma: 0.7724;    alpha: 0.0927
# Epoch 765;    Neuron [5, 9];    	Sigma: 0.7690;    alpha: 0.0923
# Epoch 766;    Neuron [1, 9];    	Sigma: 0.7656;    alpha: 0.0919
# Epoch 767;    Neuron [5, 8];    	Sigma: 0.7622;    alpha: 0.0915
# Epoch 768;    Neuron [9, 5];    	Sigma: 0.7589;    alpha: 0.0911
# Epoch 769;    Neuron [9, 3];    	Sigma: 0.7555;    alpha: 0.0907
# Epoch 770;    Neuron [1, 6];    	Sigma: 0.7522;    alpha: 0.0903
# Epoch 771;    Neuron [6, 5];    	Sigma: 0.7489;    alpha: 0.0899
# Epoch 772;    Neuron [5, 3];    	Sigma: 0.7456;    alpha: 0.0895
# Epoch 773;    Neuron [0, 6];    	Sigma: 0.7423;    alpha: 0.0891
# Epoch 774;    Neuron [5, 8];    	Sigma: 0.7391;    alpha: 0.0887
# Epoch 775;    Neuron [2, 1];    	Sigma: 0.7358;    alpha: 0.0883
# Epoch 776;    Neuron [5, 8];    	Sigma: 0.7326;    alpha: 0.0879
# Epoch 777;    Neuron [5, 4];    	Sigma: 0.7294;    alpha: 0.0875
# Epoch 778;    Neuron [0, 2];    	Sigma: 0.7262;    alpha: 0.0871
# Epoch 779;    Neuron [3, 7];    	Sigma: 0.7230;    alpha: 0.0868
# Epoch 780;    Neuron [0, 0];    	Sigma: 0.7198;    alpha: 0.0864
# Epoch 781;    Neuron [1, 9];    	Sigma: 0.7167;    alpha: 0.0860
# Epoch 782;    Neuron [4, 7];    	Sigma: 0.7135;    alpha: 0.0856
# Epoch 783;    Neuron [0, 1];    	Sigma: 0.7104;    alpha: 0.0852
# Epoch 784;    Neuron [2, 1];    	Sigma: 0.7073;    alpha: 0.0849
# Epoch 785;    Neuron [4, 3];    	Sigma: 0.7042;    alpha: 0.0845
# Epoch 786;    Neuron [8, 8];    	Sigma: 0.7011;    alpha: 0.0841
# Epoch 787;    Neuron [7, 8];    	Sigma: 0.6981;    alpha: 0.0838
# Epoch 788;    Neuron [6, 6];    	Sigma: 0.6950;    alpha: 0.0834
# Epoch 789;    Neuron [8, 1];    	Sigma: 0.6920;    alpha: 0.0830
# Epoch 790;    Neuron [5, 5];    	Sigma: 0.6890;    alpha: 0.0827
# Epoch 791;    Neuron [9, 3];    	Sigma: 0.6860;    alpha: 0.0823
# Epoch 792;    Neuron [4, 7];    	Sigma: 0.6830;    alpha: 0.0820
# Epoch 793;    Neuron [3, 9];    	Sigma: 0.6800;    alpha: 0.0816
# Epoch 794;    Neuron [6, 3];    	Sigma: 0.6771;    alpha: 0.0812
# Epoch 795;    Neuron [4, 7];    	Sigma: 0.6741;    alpha: 0.0809
# Epoch 796;    Neuron [8, 8];    	Sigma: 0.6712;    alpha: 0.0805
# Epoch 797;    Neuron [6, 4];    	Sigma: 0.6683;    alpha: 0.0802
# Epoch 798;    Neuron [4, 7];    	Sigma: 0.6654;    alpha: 0.0798
# Epoch 799;    Neuron [1, 0];    	Sigma: 0.6625;    alpha: 0.0795
# Epoch 800;    Neuron [2, 8];    	Sigma: 0.6596;    alpha: 0.0792
# Epoch 801;    Neuron [9, 2];    	Sigma: 0.6568;    alpha: 0.0788
# Epoch 802;    Neuron [4, 5];    	Sigma: 0.6539;    alpha: 0.0785
# Epoch 803;    Neuron [3, 2];    	Sigma: 0.6511;    alpha: 0.0781
# Epoch 804;    Neuron [7, 5];    	Sigma: 0.6483;    alpha: 0.0778
# Epoch 805;    Neuron [7, 8];    	Sigma: 0.6455;    alpha: 0.0775
# Epoch 806;    Neuron [9, 9];    	Sigma: 0.6427;    alpha: 0.0771
# Epoch 807;    Neuron [6, 8];    	Sigma: 0.6399;    alpha: 0.0768
# Epoch 808;    Neuron [1, 0];    	Sigma: 0.6372;    alpha: 0.0765
# Epoch 809;    Neuron [4, 1];    	Sigma: 0.6344;    alpha: 0.0761
# Epoch 810;    Neuron [5, 2];    	Sigma: 0.6317;    alpha: 0.0758
# Epoch 811;    Neuron [1, 0];    	Sigma: 0.6290;    alpha: 0.0755
# Epoch 812;    Neuron [0, 1];    	Sigma: 0.6263;    alpha: 0.0752
# Epoch 813;    Neuron [0, 1];    	Sigma: 0.6236;    alpha: 0.0748
# Epoch 814;    Neuron [2, 0];    	Sigma: 0.6209;    alpha: 0.0745
# Epoch 815;    Neuron [0, 2];    	Sigma: 0.6182;    alpha: 0.0742
# Epoch 816;    Neuron [3, 6];    	Sigma: 0.6156;    alpha: 0.0739
# Epoch 817;    Neuron [4, 7];    	Sigma: 0.6130;    alpha: 0.0736
# Epoch 818;    Neuron [3, 6];    	Sigma: 0.6103;    alpha: 0.0732
# Epoch 819;    Neuron [1, 9];    	Sigma: 0.6077;    alpha: 0.0729
# Epoch 820;    Neuron [3, 1];    	Sigma: 0.6051;    alpha: 0.0726
# Epoch 821;    Neuron [7, 7];    	Sigma: 0.6025;    alpha: 0.0723
# Epoch 822;    Neuron [3, 0];    	Sigma: 0.5999;    alpha: 0.0720
# Epoch 823;    Neuron [5, 8];    	Sigma: 0.5974;    alpha: 0.0717
# Epoch 824;    Neuron [6, 3];    	Sigma: 0.5948;    alpha: 0.0714
# Epoch 825;    Neuron [0, 0];    	Sigma: 0.5923;    alpha: 0.0711
# Epoch 826;    Neuron [0, 2];    	Sigma: 0.5898;    alpha: 0.0708
# Epoch 827;    Neuron [3, 1];    	Sigma: 0.5873;    alpha: 0.0705
# Epoch 828;    Neuron [1, 1];    	Sigma: 0.5848;    alpha: 0.0702
# Epoch 829;    Neuron [2, 8];    	Sigma: 0.5823;    alpha: 0.0699
# Epoch 830;    Neuron [3, 6];    	Sigma: 0.5798;    alpha: 0.0696
# Epoch 831;    Neuron [4, 7];    	Sigma: 0.5773;    alpha: 0.0693
# Epoch 832;    Neuron [2, 1];    	Sigma: 0.5749;    alpha: 0.0690
# Epoch 833;    Neuron [2, 1];    	Sigma: 0.5724;    alpha: 0.0687
# Epoch 834;    Neuron [1, 0];    	Sigma: 0.5700;    alpha: 0.0684
# Epoch 835;    Neuron [1, 0];    	Sigma: 0.5676;    alpha: 0.0681
# Epoch 836;    Neuron [7, 6];    	Sigma: 0.5652;    alpha: 0.0678
# Epoch 837;    Neuron [6, 7];    	Sigma: 0.5628;    alpha: 0.0675
# Epoch 838;    Neuron [5, 9];    	Sigma: 0.5604;    alpha: 0.0672
# Epoch 839;    Neuron [8, 8];    	Sigma: 0.5580;    alpha: 0.0670
# Epoch 840;    Neuron [4, 6];    	Sigma: 0.5557;    alpha: 0.0667
# Epoch 841;    Neuron [8, 1];    	Sigma: 0.5533;    alpha: 0.0664
# Epoch 842;    Neuron [0, 1];    	Sigma: 0.5510;    alpha: 0.0661
# Epoch 843;    Neuron [1, 0];    	Sigma: 0.5487;    alpha: 0.0658
# Epoch 844;    Neuron [2, 0];    	Sigma: 0.5464;    alpha: 0.0656
# Epoch 845;    Neuron [0, 1];    	Sigma: 0.5441;    alpha: 0.0653
# Epoch 846;    Neuron [9, 3];    	Sigma: 0.5418;    alpha: 0.0650
# Epoch 847;    Neuron [8, 4];    	Sigma: 0.5395;    alpha: 0.0647
# Epoch 848;    Neuron [2, 1];    	Sigma: 0.5372;    alpha: 0.0645
# Epoch 849;    Neuron [4, 1];    	Sigma: 0.5350;    alpha: 0.0642
# Epoch 850;    Neuron [9, 7];    	Sigma: 0.5327;    alpha: 0.0639
# Epoch 851;    Neuron [0, 1];    	Sigma: 0.5305;    alpha: 0.0637
# Epoch 852;    Neuron [8, 2];    	Sigma: 0.5283;    alpha: 0.0634
# Epoch 853;    Neuron [4, 6];    	Sigma: 0.5261;    alpha: 0.0631
# Epoch 854;    Neuron [4, 7];    	Sigma: 0.5239;    alpha: 0.0629
# Epoch 855;    Neuron [5, 4];    	Sigma: 0.5217;    alpha: 0.0626
# Epoch 856;    Neuron [9, 3];    	Sigma: 0.5195;    alpha: 0.0623
# Epoch 857;    Neuron [2, 5];    	Sigma: 0.5173;    alpha: 0.0621
# Epoch 858;    Neuron [9, 3];    	Sigma: 0.5152;    alpha: 0.0618
# Epoch 859;    Neuron [1, 1];    	Sigma: 0.5130;    alpha: 0.0616
# Epoch 860;    Neuron [3, 1];    	Sigma: 0.5109;    alpha: 0.0613
# Epoch 861;    Neuron [7, 1];    	Sigma: 0.5087;    alpha: 0.0610
# Epoch 862;    Neuron [4, 9];    	Sigma: 0.5066;    alpha: 0.0608
# Epoch 863;    Neuron [4, 7];    	Sigma: 0.5045;    alpha: 0.0605
# Epoch 864;    Neuron [5, 0];    	Sigma: 0.5024;    alpha: 0.0603
# Epoch 865;    Neuron [7, 7];    	Sigma: 0.5003;    alpha: 0.0600
# Epoch 866;    Neuron [9, 6];    	Sigma: 0.4983;    alpha: 0.0598
# Epoch 867;    Neuron [8, 2];    	Sigma: 0.4962;    alpha: 0.0595
# Epoch 868;    Neuron [2, 1];    	Sigma: 0.4941;    alpha: 0.0593
# Epoch 869;    Neuron [8, 3];    	Sigma: 0.4921;    alpha: 0.0591
# Epoch 870;    Neuron [6, 0];    	Sigma: 0.4900;    alpha: 0.0588
# Epoch 871;    Neuron [0, 1];    	Sigma: 0.4880;    alpha: 0.0586
# Epoch 872;    Neuron [2, 0];    	Sigma: 0.4860;    alpha: 0.0583
# Epoch 873;    Neuron [6, 4];    	Sigma: 0.4840;    alpha: 0.0581
# Epoch 874;    Neuron [3, 9];    	Sigma: 0.4820;    alpha: 0.0578
# Epoch 875;    Neuron [0, 3];    	Sigma: 0.4800;    alpha: 0.0576
# Epoch 876;    Neuron [1, 9];    	Sigma: 0.4780;    alpha: 0.0574
# Epoch 877;    Neuron [0, 2];    	Sigma: 0.4761;    alpha: 0.0571
# Epoch 878;    Neuron [4, 5];    	Sigma: 0.4741;    alpha: 0.0569
# Epoch 879;    Neuron [9, 3];    	Sigma: 0.4721;    alpha: 0.0567
# Epoch 880;    Neuron [3, 9];    	Sigma: 0.4702;    alpha: 0.0564
# Epoch 881;    Neuron [4, 4];    	Sigma: 0.4683;    alpha: 0.0562
# Epoch 882;    Neuron [2, 1];    	Sigma: 0.4664;    alpha: 0.0560
# Epoch 883;    Neuron [0, 8];    	Sigma: 0.4644;    alpha: 0.0557
# Epoch 884;    Neuron [7, 8];    	Sigma: 0.4625;    alpha: 0.0555
# Epoch 885;    Neuron [5, 4];    	Sigma: 0.4606;    alpha: 0.0553
# Epoch 886;    Neuron [4, 1];    	Sigma: 0.4588;    alpha: 0.0551
# Epoch 887;    Neuron [4, 5];    	Sigma: 0.4569;    alpha: 0.0548
# Epoch 888;    Neuron [6, 0];    	Sigma: 0.4550;    alpha: 0.0546
# Epoch 889;    Neuron [4, 5];    	Sigma: 0.4532;    alpha: 0.0544
# Epoch 890;    Neuron [7, 7];    	Sigma: 0.4513;    alpha: 0.0542
# Epoch 891;    Neuron [5, 7];    	Sigma: 0.4495;    alpha: 0.0539
# Epoch 892;    Neuron [2, 2];    	Sigma: 0.4476;    alpha: 0.0537
# Epoch 893;    Neuron [0, 3];    	Sigma: 0.4458;    alpha: 0.0535
# Epoch 894;    Neuron [5, 7];    	Sigma: 0.4440;    alpha: 0.0533
# Epoch 895;    Neuron [8, 0];    	Sigma: 0.4422;    alpha: 0.0531
# Epoch 896;    Neuron [7, 7];    	Sigma: 0.4404;    alpha: 0.0528
# Epoch 897;    Neuron [7, 5];    	Sigma: 0.4386;    alpha: 0.0526
# Epoch 898;    Neuron [9, 3];    	Sigma: 0.4368;    alpha: 0.0524
# Epoch 899;    Neuron [7, 1];    	Sigma: 0.4351;    alpha: 0.0522
# Epoch 900;    Neuron [0, 2];    	Sigma: 0.4333;    alpha: 0.0520
# Epoch 901;    Neuron [1, 0];    	Sigma: 0.4315;    alpha: 0.0518
# Epoch 902;    Neuron [9, 1];    	Sigma: 0.4298;    alpha: 0.0516
# Epoch 903;    Neuron [4, 3];    	Sigma: 0.4280;    alpha: 0.0514
# Epoch 904;    Neuron [9, 3];    	Sigma: 0.4263;    alpha: 0.0512
# Epoch 905;    Neuron [6, 4];    	Sigma: 0.4246;    alpha: 0.0510
# Epoch 906;    Neuron [3, 7];    	Sigma: 0.4229;    alpha: 0.0507
# Epoch 907;    Neuron [2, 9];    	Sigma: 0.4212;    alpha: 0.0505
# Epoch 908;    Neuron [8, 1];    	Sigma: 0.4195;    alpha: 0.0503
# Epoch 909;    Neuron [7, 4];    	Sigma: 0.4178;    alpha: 0.0501
# Epoch 910;    Neuron [2, 6];    	Sigma: 0.4161;    alpha: 0.0499
# Epoch 911;    Neuron [8, 6];    	Sigma: 0.4144;    alpha: 0.0497
# Epoch 912;    Neuron [1, 1];    	Sigma: 0.4128;    alpha: 0.0495
# Epoch 913;    Neuron [1, 9];    	Sigma: 0.4111;    alpha: 0.0493
# Epoch 914;    Neuron [6, 6];    	Sigma: 0.4095;    alpha: 0.0491
# Epoch 915;    Neuron [3, 1];    	Sigma: 0.4078;    alpha: 0.0489
# Epoch 916;    Neuron [3, 8];    	Sigma: 0.4062;    alpha: 0.0487
# Epoch 917;    Neuron [4, 7];    	Sigma: 0.4046;    alpha: 0.0485
# Epoch 918;    Neuron [7, 3];    	Sigma: 0.4029;    alpha: 0.0484
# Epoch 919;    Neuron [4, 7];    	Sigma: 0.4013;    alpha: 0.0482
# Epoch 920;    Neuron [7, 1];    	Sigma: 0.3997;    alpha: 0.0480
# Epoch 921;    Neuron [8, 0];    	Sigma: 0.3981;    alpha: 0.0478
# Epoch 922;    Neuron [6, 8];    	Sigma: 0.3966;    alpha: 0.0476
# Epoch 923;    Neuron [2, 2];    	Sigma: 0.3950;    alpha: 0.0474
# Epoch 924;    Neuron [8, 5];    	Sigma: 0.3934;    alpha: 0.0472
# Epoch 925;    Neuron [8, 8];    	Sigma: 0.3918;    alpha: 0.0470
# Epoch 926;    Neuron [0, 1];    	Sigma: 0.3903;    alpha: 0.0468
# Epoch 927;    Neuron [3, 9];    	Sigma: 0.3887;    alpha: 0.0466
# Epoch 928;    Neuron [2, 5];    	Sigma: 0.3872;    alpha: 0.0465
# Epoch 929;    Neuron [3, 1];    	Sigma: 0.3856;    alpha: 0.0463
# Epoch 930;    Neuron [3, 5];    	Sigma: 0.3841;    alpha: 0.0461
# Epoch 931;    Neuron [2, 4];    	Sigma: 0.3826;    alpha: 0.0459
# Epoch 932;    Neuron [9, 3];    	Sigma: 0.3811;    alpha: 0.0457
# Epoch 933;    Neuron [0, 0];    	Sigma: 0.3796;    alpha: 0.0455
# Epoch 934;    Neuron [1, 3];    	Sigma: 0.3781;    alpha: 0.0454
# Epoch 935;    Neuron [0, 9];    	Sigma: 0.3766;    alpha: 0.0452
# Epoch 936;    Neuron [8, 8];    	Sigma: 0.3751;    alpha: 0.0450
# Epoch 937;    Neuron [3, 5];    	Sigma: 0.3736;    alpha: 0.0448
# Epoch 938;    Neuron [7, 9];    	Sigma: 0.3721;    alpha: 0.0447
# Epoch 939;    Neuron [3, 9];    	Sigma: 0.3707;    alpha: 0.0445
# Epoch 940;    Neuron [0, 2];    	Sigma: 0.3692;    alpha: 0.0443
# Epoch 941;    Neuron [3, 1];    	Sigma: 0.3678;    alpha: 0.0441
# Epoch 942;    Neuron [2, 2];    	Sigma: 0.3663;    alpha: 0.0440
# Epoch 943;    Neuron [1, 0];    	Sigma: 0.3649;    alpha: 0.0438
# Epoch 944;    Neuron [4, 7];    	Sigma: 0.3635;    alpha: 0.0436
# Epoch 945;    Neuron [0, 1];    	Sigma: 0.3620;    alpha: 0.0434
# Epoch 946;    Neuron [0, 1];    	Sigma: 0.3606;    alpha: 0.0433
# Epoch 947;    Neuron [9, 0];    	Sigma: 0.3592;    alpha: 0.0431
# Epoch 948;    Neuron [2, 0];    	Sigma: 0.3578;    alpha: 0.0429
# Epoch 949;    Neuron [0, 2];    	Sigma: 0.3564;    alpha: 0.0428
# Epoch 950;    Neuron [5, 4];    	Sigma: 0.3550;    alpha: 0.0426
# Epoch 951;    Neuron [3, 9];    	Sigma: 0.3536;    alpha: 0.0424
# Epoch 952;    Neuron [4, 7];    	Sigma: 0.3522;    alpha: 0.0423
# Epoch 953;    Neuron [6, 3];    	Sigma: 0.3509;    alpha: 0.0421
# Epoch 954;    Neuron [4, 3];    	Sigma: 0.3495;    alpha: 0.0419
# Epoch 955;    Neuron [7, 1];    	Sigma: 0.3481;    alpha: 0.0418
# Epoch 956;    Neuron [9, 6];    	Sigma: 0.3468;    alpha: 0.0416
# Epoch 957;    Neuron [6, 7];    	Sigma: 0.3454;    alpha: 0.0415
# Epoch 958;    Neuron [3, 3];    	Sigma: 0.3441;    alpha: 0.0413
# Epoch 959;    Neuron [4, 4];    	Sigma: 0.3428;    alpha: 0.0411
# Epoch 960;    Neuron [0, 2];    	Sigma: 0.3414;    alpha: 0.0410
# Epoch 961;    Neuron [6, 4];    	Sigma: 0.3401;    alpha: 0.0408
# Epoch 962;    Neuron [5, 1];    	Sigma: 0.3388;    alpha: 0.0407
# Epoch 963;    Neuron [3, 1];    	Sigma: 0.3375;    alpha: 0.0405
# Epoch 964;    Neuron [2, 1];    	Sigma: 0.3362;    alpha: 0.0403
# Epoch 965;    Neuron [7, 7];    	Sigma: 0.3349;    alpha: 0.0402
# Epoch 966;    Neuron [3, 1];    	Sigma: 0.3336;    alpha: 0.0400
# Epoch 967;    Neuron [5, 8];    	Sigma: 0.3323;    alpha: 0.0399
# Epoch 968;    Neuron [3, 9];    	Sigma: 0.3310;    alpha: 0.0397
# Epoch 969;    Neuron [8, 0];    	Sigma: 0.3298;    alpha: 0.0396
# Epoch 970;    Neuron [5, 6];    	Sigma: 0.3285;    alpha: 0.0394
# Epoch 971;    Neuron [4, 5];    	Sigma: 0.3272;    alpha: 0.0393
# Epoch 972;    Neuron [5, 3];    	Sigma: 0.3260;    alpha: 0.0391
# Epoch 973;    Neuron [2, 3];    	Sigma: 0.3247;    alpha: 0.0390
# Epoch 974;    Neuron [4, 3];    	Sigma: 0.3235;    alpha: 0.0388
# Epoch 975;    Neuron [3, 4];    	Sigma: 0.3222;    alpha: 0.0387
# Epoch 976;    Neuron [3, 0];    	Sigma: 0.3210;    alpha: 0.0385
# Epoch 977;    Neuron [8, 6];    	Sigma: 0.3198;    alpha: 0.0384
# Epoch 978;    Neuron [5, 8];    	Sigma: 0.3185;    alpha: 0.0382
# Epoch 979;    Neuron [0, 9];    	Sigma: 0.3173;    alpha: 0.0381
# Epoch 980;    Neuron [2, 3];    	Sigma: 0.3161;    alpha: 0.0379
# Epoch 981;    Neuron [2, 0];    	Sigma: 0.3149;    alpha: 0.0378
# Epoch 982;    Neuron [2, 1];    	Sigma: 0.3137;    alpha: 0.0376
# Epoch 983;    Neuron [9, 9];    	Sigma: 0.3125;    alpha: 0.0375
# Epoch 984;    Neuron [8, 5];    	Sigma: 0.3113;    alpha: 0.0374
# Epoch 985;    Neuron [0, 2];    	Sigma: 0.3101;    alpha: 0.0372
# Epoch 986;    Neuron [3, 1];    	Sigma: 0.3090;    alpha: 0.0371
# Epoch 987;    Neuron [4, 3];    	Sigma: 0.3078;    alpha: 0.0369
# Epoch 988;    Neuron [5, 6];    	Sigma: 0.3066;    alpha: 0.0368
# Epoch 989;    Neuron [8, 1];    	Sigma: 0.3055;    alpha: 0.0367
# Epoch 990;    Neuron [8, 0];    	Sigma: 0.3043;    alpha: 0.0365
# Epoch 991;    Neuron [0, 2];    	Sigma: 0.3031;    alpha: 0.0364
# Epoch 992;    Neuron [1, 1];    	Sigma: 0.3020;    alpha: 0.0362
# Epoch 993;    Neuron [6, 8];    	Sigma: 0.3009;    alpha: 0.0361
# Epoch 994;    Neuron [8, 0];    	Sigma: 0.2997;    alpha: 0.0360
# Epoch 995;    Neuron [6, 8];    	Sigma: 0.2986;    alpha: 0.0358
# Epoch 996;    Neuron [6, 5];    	Sigma: 0.2975;    alpha: 0.0357
# Epoch 997;    Neuron [5, 3];    	Sigma: 0.2963;    alpha: 0.0356
# Epoch 998;    Neuron [4, 1];    	Sigma: 0.2952;    alpha: 0.0354
# Epoch 999;    Neuron [3, 1];    	Sigma: 0.2941;    alpha: 0.0353
# Error history plot done!

# %%
targets = np.array(500 * [0] + 500 * [1])  # create some dummy target values

# %%
targets.shape
# Out:
# (1000,)

# %%
targets.dtype
# Out:
# dtype('int32')

# %%
# now visualize the learned representation with the class labels
som.plot_point_map(data, targets, ['Class 0', 'Class 1'], filename='images/som.png')
som.plot_class_density(data, targets, t=0, name='Class 0', filename='images/class_0.png')
som.plot_distance_map(filename='images/distance_map.png')  # plot the distance map after training
# Out:
# Point map plot done!
# Class density plot done!
# Distance map plot done!

# %%
# predicting the class of a new, unknown datapoint
datapoint = np.random.normal(loc=.0, scale=0.5, size=(1, 36))
print("Labels of neighboring datapoints: ", som.get_neighbors(datapoint, data, targets, d=0))
# Out:
# Winner neuron of given data point: [9, 4]
# Labels of neighboring datapoints:  [0 1]

# %%
label0=som.get_neighbors(datapoint, data, targets, d=0)
# Out:
# Winner neuron of given data point: [9, 4]

# %%
label1=som.get_neighbors(datapoint, data, targets, d=1)
# Out:
# Winner neuron of given data point: [9, 4]

# %%
print(datapoint)
# Out:
# [[ 0.0525451   0.66143617  0.23166435  0.28440746  0.4901423  -0.23031157
#    0.39882488 -0.2298456   0.05047519  0.17511312 -0.12922637 -0.26360189
#    0.66480106  0.46758137  0.41611253  0.91950348 -0.14982816  0.27770298
#    0.56097588 -0.11980151  0.54197093  0.56706564  0.73271592  0.05149198
#   -0.32299662  0.25452696  0.19662583  0.44432094 -0.2741594  -0.70919623
#    0.12463728  0.3248366   1.06644982 -0.00138166  0.16752704 -0.21856066]]

# %%
datapoint.shape
# Out:
# (1, 36)

# %%
datapoint.dtype
# Out:
# dtype('float64')

# %%
# transform data into the SOM space
newdata = np.random.normal(loc=.25, scale=0.5, size=(10, 36))
transformed = som.transform(newdata)
print("Old shape of the data:", newdata.shape)
print("New shape of the data:", transformed.shape)
# Out:
# Old shape of the data: (10, 36)
# New shape of the data: (10, 10, 10)
